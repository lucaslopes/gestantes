# %% [raw]
# ---
# title: "Rede de Deslocamento"
# ---

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from pathlib import Path
from zipfile import ZipFile
from datatable import dt, f, by
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn3
from plotly import express as px, io as pio

pd.options.plotting.backend = 'plotly'
pio.renderers.default = 'plotly_mimetype+notebook_connected'
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# # Bases

# %% [markdown]
# ## SINASC

# %%
path_sinasc_sus = f'{Path.home()}/Databases/SINASC/sinasc_sus.csv.gzip'
df_sinasc = pd.read_csv(path_sinasc_sus, low_memory=False)
df_sinasc
# Out:
#            ano     cnes  hosp_municipio  res_municipio  hosp_regiao_saude  \
# 0         2010  2798484          110030         120040               1103
# 1         2010  5701929          120001         120001               1201
# 2         2010  5701929          120001         120001               1201
# 3         2010  5701929          120001         120001               1201
# 4         2010  5701929          120001         120001               1201
# ...        ...      ...             ...            ...                ...
# 22773577  2019  2361787          520110         170730               5211
# 22773578  2019  2338564          520870         171110               5201
# 22773579  2019    10537          530010         170240               5301
# 22773580  2019  5717515          530010         170610               5301
# 22773581  2019  5717515          530010         172100               5301
#
#           res_regiao_saude  parto_normal  n_gestados  n_pre_natal  idade  \
# 0                     1201          True           1            4     20
# 1                     1201          True           1            3     21
# 2                     1201          True           1            3     31
# 3                     1201          True           1            4     23
# 4                     1201          True           1            4     26
# ...                    ...           ...         ...          ...    ...
# 22773577              1710         False           1            3     18
# 22773578              1704         False           1            4     27
# 22773579              1709         False           1            3     36
# 22773580              1710         False           1            3     21
# 22773581              1705          True           1            4     21
#
#           nivel_escolaridade raca_cor nasc_raca_cor sexo_fem  nasc_peso  \
# 0                          3      NaN        Branca    False     3550.0
# 1                          4      NaN         Parda     True     3000.0
# 2                          3      NaN         Parda     True     3000.0
# 3                          3      NaN         Parda    False     3900.0
# 4                          4      NaN         Parda     True     3250.0
# ...                      ...      ...           ...      ...        ...
# 22773577                   3    Parda         Parda     True     2840.0
# 22773578                   4    Parda         Parda     True     3082.0
# 22773579                   5      NaN      Ignorado      NaN     2870.0
# 22773580                   4    Parda         Parda    False     2554.0
# 22773581                   4    Parda         Parda     True     2610.0
#
#           nasc_apgar1  nasc_apgar5 periodo
# 0                 8.0          9.0   antes
# 1                 9.0         10.0   antes
# 2                 9.0         10.0   antes
# 3                 7.0          9.0   antes
# 4                 7.0         10.0   antes
# ...               ...          ...     ...
# 22773577          8.0          9.0  depois
# 22773578          8.0          9.0  depois
# 22773579          8.0          9.0  depois
# 22773580          8.0          9.0  depois
# 22773581          8.0          9.0  depois
#
# [22773582 rows x 18 columns]

# %%
df_sinasc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22773582 entries, 0 to 22773581
# Data columns (total 18 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ano                 int64
#  1   cnes                int64
#  2   hosp_municipio      int64
#  3   res_municipio       int64
#  4   hosp_regiao_saude   int64
#  5   res_regiao_saude    int64
#  6   parto_normal        bool
#  7   n_gestados          int64
#  8   n_pre_natal         int64
#  9   idade               int64
#  10  nivel_escolaridade  int64
#  11  raca_cor            object
#  12  nasc_raca_cor       object
#  13  sexo_fem            object
#  14  nasc_peso           float64
#  15  nasc_apgar1         float64
#  16  nasc_apgar5         float64
#  17  periodo             object
# dtypes: bool(1), float64(3), int64(10), object(4)
# memory usage: 2.9+ GB

# %% [markdown]
# ## Municípios

# %%
path_muns = f'{Path.home()}/Databases/MUNICIPIOS/municipios.csv.gzip'
df_muns = pd.read_csv(path_muns)
df_muns
# Out:
#       cod_ibge        regiao  uf  cod_uf           nome_uf  \
# 0       110000         Norte  RO      11          RONDONIA
# 1       110001         Norte  RO      11          RONDONIA
# 2       110002         Norte  RO      11          RONDONIA
# 3       110003         Norte  RO      11          RONDONIA
# 4       110004         Norte  RO      11          RONDONIA
# ...        ...           ...  ..     ...               ...
# 4789    522200  Centro-Oeste  GO      52             GOIAS
# 4790    522205  Centro-Oeste  GO      52             GOIAS
# 4791    522220  Centro-Oeste  GO      52             GOIAS
# 4792    522230  Centro-Oeste  GO      52             GOIAS
# 4793    530010  Centro-Oeste  DF      53  DISTRITO FEDERAL
#
#                     municipio                     nome  capital  fronteira  \
# 0     Município ignorado - RO  MUNICIPIO IGNORADO - RO    False      False
# 1       Alta Floresta D'Oeste    ALTA FLORESTA D'OESTE    False       True
# 2                   Ariquemes                ARIQUEMES    False      False
# 3                      Cabixi                   CABIXI    False       True
# 4                      Cacoal                   CACOAL    False      False
# ...                       ...                      ...      ...        ...
# 4789               Vianópolis               VIANOPOLIS    False      False
# 4790           Vicentinópolis           VICENTINOPOLIS    False      False
# 4791                 Vila Boa                 VILA BOA    False      False
# 4792            Vila Propício            VILA PROPICIO    False      False
# 4793                 Brasília                 BRASILIA     True      False
#
#       amazonia  macroregiao_saude  regiao_saude  microregiao_saude   latitude  \
# 0        False               1100          1100              11000   0.000000
# 1         True               1190          1102              11900 -11.929000
# 2         True               1190          1104              11900  -9.913000
# 3         True               1190          1103              11900 -13.492000
# 4         True               1190          1102              11900 -11.438000
# ...        ...                ...           ...                ...        ...
# 4789     False               5201          5202              52900 -16.742001
# 4790     False               5201          5202              52900 -17.735001
# 4791     False               5202          5206              52900 -15.038000
# 4792     False               5203          5212              52900 -15.457000
# 4793     False               5301          5301              53001 -15.780000
#
#       longitude  altitude         area
# 0      0.000000       0.0     0.000000
# 1    -61.995998     350.0  7066.702148
# 2    -63.041000     142.0  4426.558105
# 3    -60.544998     230.0  1314.354980
# 4    -61.448002     200.0  3792.637939
# ...         ...       ...          ...
# 4789 -48.515999    1002.0   954.278992
# 4790 -49.806000     646.0   737.250977
# 4791 -47.058998       0.0  1060.170044
# 4792 -48.889000     744.0  2181.574951
# 4793 -47.930000    1171.0  5801.937012
#
# [4794 rows x 17 columns]

# %%
df_muns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4794 entries, 0 to 4793
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   cod_ibge           4794 non-null   int64
#  1   regiao             4794 non-null   object
#  2   uf                 4794 non-null   object
#  3   cod_uf             4794 non-null   int64
#  4   nome_uf            4794 non-null   object
#  5   municipio          4794 non-null   object
#  6   nome               4794 non-null   object
#  7   capital            4794 non-null   bool
#  8   fronteira          4794 non-null   bool
#  9   amazonia           4794 non-null   bool
#  10  macroregiao_saude  4794 non-null   int64
#  11  regiao_saude       4794 non-null   int64
#  12  microregiao_saude  4794 non-null   int64
#  13  latitude           4790 non-null   float64
#  14  longitude          4790 non-null   float64
#  15  altitude           4790 non-null   float64
#  16  area               4790 non-null   float64
# dtypes: bool(3), float64(4), int64(5), object(5)
# memory usage: 538.5+ KB

# %% [markdown]
# ## Distâncias

# %%
path_dist = f'{Path.home()}/Databases/DISTANCIAS/matriz_distancias.zip'
df_dist = pd.read_csv(path_dist, low_memory=False)
df_dist
# Out:
#           origem  destino   distancia     tempo
# 0         110001   110001    0.000000  0.000000
# 1         110001   110002  309.050000  6.169056
# 2         110001   110003  399.499700  6.289056
# 3         110001   110004   81.201103  1.917750
# 4         110001   110005  391.704300  6.136361
# ...          ...      ...         ...       ...
# 31024895  530010   522200  161.728900  2.356000
# 31024896  530010   522205  382.708800  5.479556
# 31024897  530010   522220  161.603400  2.248944
# 31024898  530010   522230  190.000900  3.216083
# 31024899  530010   530010    0.000000  0.000000
#
# [31024900 rows x 4 columns]

# %%
df_dist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31024900 entries, 0 to 31024899
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   origem     int64
#  1   destino    int64
#  2   distancia  float64
#  3   tempo      float64
# dtypes: float64(2), int64(2)
# memory usage: 946.8 MB

# %% [markdown]
# ## Indicador SocioEconômico

# %%
path_socioeco = f'{Path.home()}/Databases/HEALTH/health_regions.csv'
df_socioeco = pd.read_csv(path_socioeco)
df_socioeco
# Out:
#       UF       Município  Cód IBGE  Cód Região de Saúde  \
# 0     AC      Acrelândia    120001                12002
# 1     AC    Assis Brasil    120005                12001
# 2     AC       Brasiléia    120010                12001
# 3     AC          Bujari    120013                12002
# 4     AC        Capixaba    120017                12002
# ...   ..             ...       ...                  ...
# 5566  TO  Tocantinópolis    172120                17002
# 5567  TO        Tupirama    172125                17004
# 5568  TO      Tupiratins    172130                17004
# 5569  TO    Wanderlândia    172208                17001
# 5570  TO         Xambioá    172210                17001
#
#          Nome da Região de Saúde  Grupo
# 0             Baixo Acre e Purus      2
# 1                      Alto Acre      1
# 2                      Alto Acre      1
# 3             Baixo Acre e Purus      2
# 4             Baixo Acre e Purus      2
# ...                          ...    ...
# 5566            Bico do Papagaio      1
# 5567  Cerrado Tocantins Araguaia      2
# 5568  Cerrado Tocantins Araguaia      2
# 5569        Médio Norte Araguaia      3
# 5570        Médio Norte Araguaia      3
#
# [5571 rows x 6 columns]

# %%
df_socioeco[['Cód IBGE', 'Grupo']]
# Out:
#       Cód IBGE  Grupo
# 0       120001      2
# 1       120005      1
# 2       120010      1
# 3       120013      2
# 4       120017      2
# ...        ...    ...
# 5566    172120      1
# 5567    172125      2
# 5568    172130      2
# 5569    172208      3
# 5570    172210      3
#
# [5571 rows x 2 columns]

# %% [markdown]
# # Tabela Deslocamento

# %%
def merge_lat_lon(df_left, df_right, left_on, right_on):
  prefix = left_on.split('_')[0]
  df = pd.merge(df_left, df_right, how='left', left_on=left_on, right_on=right_on)
  df = df.rename(columns={
    'latitude': f'{prefix}_latitude',
    'longitude': f'{prefix}_longitude'})
  df = df.drop(right_on, axis=1)
  return df

# %%
cols = ['periodo', 'parto_normal', 'res_municipio', 'hosp_municipio', 'res_regiao_saude', 'hosp_regiao_saude', 'cnes']
df_deslc = df_sinasc[cols]
df_deslc = df_deslc[df_deslc['periodo'] != 'durante']
df_deslc = df_deslc.groupby(
  cols, as_index=False
).size().sort_values('size', ascending=False, ignore_index=True)
df_deslc = df_deslc.rename(columns={'size': 'nascimentos'})
df_deslc
# Out:
#        periodo  parto_normal  res_municipio  hosp_municipio  res_regiao_saude  \
# 0        antes          True         130260          130260              1301
# 1        antes          True         355030          355030              3501
# 2       depois         False         500270          500270              5011
# 3       depois          True         140010          140010              1401
# 4        antes          True         292740          292740              2901
# ...        ...           ...            ...             ...               ...
# 169160   antes          True         510622          510267              5114
# 169161   antes          True         510621          510340              5104
# 169162   antes          True         510621          510340              5104
# 169163   antes          True         510621          510025              5104
# 169164  depois          True         522230          530010              5212
#
#         hosp_regiao_saude     cnes  nascimentos
# 0                    1301  3151794        11011
# 1                    3501  2077388        10426
# 2                    5011     9768        10012
# 3                    1401  2566168         9647
# 4                    2901  3956369         9109
# ...                   ...      ...          ...
# 169160               5107  2396106            1
# 169161               5101  2659107            1
# 169162               5101  2311682            1
# 169163               5104  2471345            1
# 169164               5301    10545            1
#
# [169165 rows x 8 columns]

# %%
df_deslc['periodo'].value_counts()
# Out:
# antes     85023
# depois    84142
# Name: periodo, dtype: int64

# %%
df_deslc['mun_diff'] = df_deslc['res_municipio'] != df_deslc['hosp_municipio']
df_deslc['regsau_diff'] = df_deslc['res_regiao_saude'] != df_deslc['hosp_regiao_saude']
df_deslc
# Out:
#        periodo  parto_normal  res_municipio  hosp_municipio  res_regiao_saude  \
# 0        antes          True         130260          130260              1301
# 1        antes          True         355030          355030              3501
# 2       depois         False         500270          500270              5011
# 3       depois          True         140010          140010              1401
# 4        antes          True         292740          292740              2901
# ...        ...           ...            ...             ...               ...
# 169160   antes          True         510622          510267              5114
# 169161   antes          True         510621          510340              5104
# 169162   antes          True         510621          510340              5104
# 169163   antes          True         510621          510025              5104
# 169164  depois          True         522230          530010              5212
#
#         hosp_regiao_saude     cnes  nascimentos  mun_diff  regsau_diff
# 0                    1301  3151794        11011     False        False
# 1                    3501  2077388        10426     False        False
# 2                    5011     9768        10012     False        False
# 3                    1401  2566168         9647     False        False
# 4                    2901  3956369         9109     False        False
# ...                   ...      ...          ...       ...          ...
# 169160               5107  2396106            1      True         True
# 169161               5101  2659107            1      True         True
# 169162               5101  2311682            1      True         True
# 169163               5104  2471345            1      True        False
# 169164               5301    10545            1      True         True
#
# [169165 rows x 10 columns]

# %%
res_cols = [
  'cod_ibge',
  'regiao',
  'uf',
  'capital',
  'fronteira',
  'amazonia',
  'latitude',
  'longitude',]

hosp_cols = [
  'cod_ibge',
  'latitude',
  'longitude',]

# %%
df_deslc = merge_lat_lon(df_deslc, df_muns[res_cols], 'res_municipio', 'cod_ibge')
df_deslc = merge_lat_lon(df_deslc, df_muns[hosp_cols], 'hosp_municipio', 'cod_ibge')
df_deslc
# Out:
#        periodo  parto_normal  res_municipio  hosp_municipio  res_regiao_saude  \
# 0        antes          True         130260          130260              1301
# 1        antes          True         355030          355030              3501
# 2       depois         False         500270          500270              5011
# 3       depois          True         140010          140010              1401
# 4        antes          True         292740          292740              2901
# ...        ...           ...            ...             ...               ...
# 169163   antes          True         510622          510267              5114
# 169164   antes          True         510621          510340              5104
# 169165   antes          True         510621          510340              5104
# 169166   antes          True         510621          510025              5104
# 169167  depois          True         522230          530010              5212
#
#         hosp_regiao_saude     cnes  nascimentos  mun_diff  regsau_diff  \
# 0                    1301  3151794        11011     False        False
# 1                    3501  2077388        10426     False        False
# 2                    5011     9768        10012     False        False
# 3                    1401  2566168         9647     False        False
# 4                    2901  3956369         9109     False        False
# ...                   ...      ...          ...       ...          ...
# 169163               5107  2396106            1      True         True
# 169164               5101  2659107            1      True         True
# 169165               5101  2311682            1      True         True
# 169166               5104  2471345            1      True        False
# 169167               5301    10545            1      True         True
#
#               regiao   uf capital fronteira amazonia  res_latitude  \
# 0              Norte   AM    True     False     True     -3.102000
# 1            Sudeste   SP    True     False    False    -23.548000
# 2       Centro-Oeste   MS    True     False    False    -20.443001
# 3              Norte   RR    True      True     True      2.820000
# 4                NaN  NaN     NaN       NaN      NaN           NaN
# ...              ...  ...     ...       ...      ...           ...
# 169163  Centro-Oeste   MT   False     False     True    -13.838000
# 169164  Centro-Oeste   MT   False     False     True    -10.558000
# 169165  Centro-Oeste   MT   False     False     True    -10.558000
# 169166  Centro-Oeste   MT   False     False     True    -10.558000
# 169167  Centro-Oeste   GO   False     False    False    -15.457000
#
#         res_longitude  hosp_latitude  hosp_longitude
# 0          -60.025002      -3.102000      -60.025002
# 1          -46.636002     -23.548000      -46.636002
# 2          -54.646000     -20.443001      -54.646000
# 3          -60.673000       2.820000      -60.673000
# 4                 NaN            NaN             NaN
# ...               ...            ...             ...
# 169163     -56.084000     -15.547000      -55.168999
# 169164     -55.952999     -15.596000      -56.097000
# 169165     -55.952999     -15.596000      -56.097000
# 169166     -55.952999      -9.876000      -56.085999
# 169167     -48.889000     -15.780000      -47.930000
#
# [169168 rows x 19 columns]

# %%
df_deslc = pd.merge(df_deslc, df_dist, how='left', left_on=['res_municipio', 'hosp_municipio'], right_on=['origem', 'destino'])
df_deslc = df_deslc.drop(['origem', 'destino'], axis=1)
df_deslc
# Out:
#        periodo  parto_normal  res_municipio  hosp_municipio  res_regiao_saude  \
# 0        antes          True         130260          130260              1301
# 1        antes          True         355030          355030              3501
# 2       depois         False         500270          500270              5011
# 3       depois          True         140010          140010              1401
# 4        antes          True         292740          292740              2901
# ...        ...           ...            ...             ...               ...
# 169163   antes          True         510622          510267              5114
# 169164   antes          True         510621          510340              5104
# 169165   antes          True         510621          510340              5104
# 169166   antes          True         510621          510025              5104
# 169167  depois          True         522230          530010              5212
#
#         hosp_regiao_saude     cnes  nascimentos  mun_diff  regsau_diff  ...  \
# 0                    1301  3151794        11011     False        False  ...
# 1                    3501  2077388        10426     False        False  ...
# 2                    5011     9768        10012     False        False  ...
# 3                    1401  2566168         9647     False        False  ...
# 4                    2901  3956369         9109     False        False  ...
# ...                   ...      ...          ...       ...          ...  ...
# 169163               5107  2396106            1      True         True  ...
# 169164               5101  2659107            1      True         True  ...
# 169165               5101  2311682            1      True         True  ...
# 169166               5104  2471345            1      True        False  ...
# 169167               5301    10545            1      True         True  ...
#
#          uf capital fronteira amazonia res_latitude  res_longitude  \
# 0        AM    True     False     True    -3.102000     -60.025002
# 1        SP    True     False    False   -23.548000     -46.636002
# 2        MS    True     False    False   -20.443001     -54.646000
# 3        RR    True      True     True     2.820000     -60.673000
# 4       NaN     NaN       NaN      NaN          NaN            NaN
# ...     ...     ...       ...      ...          ...            ...
# 169163   MT   False     False     True   -13.838000     -56.084000
# 169164   MT   False     False     True   -10.558000     -55.952999
# 169165   MT   False     False     True   -10.558000     -55.952999
# 169166   MT   False     False     True   -10.558000     -55.952999
# 169167   GO   False     False    False   -15.457000     -48.889000
#
#         hosp_latitude  hosp_longitude  distancia     tempo
# 0           -3.102000      -60.025002     0.0000  0.000000
# 1          -23.548000      -46.636002     0.0000  0.000000
# 2          -20.443001      -54.646000     0.0000  0.000000
# 3            2.820000      -60.673000     0.0000  0.000000
# 4                 NaN             NaN     0.0000  0.000000
# ...               ...             ...        ...       ...
# 169163     -15.547000      -55.168999   391.9461  4.769250
# 169164     -15.596000      -56.097000   701.7827  9.122222
# 169165     -15.596000      -56.097000   701.7827  9.122222
# 169166      -9.876000      -56.085999   117.8282  1.871250
# 169167     -15.780000      -47.930000   190.0009  3.216083
#
# [169168 rows x 21 columns]

# %%
df_deslc = pd.merge(df_deslc, df_socioeco[['Cód IBGE', 'Grupo']], how='left', left_on='res_municipio', right_on='Cód IBGE')
df_deslc = df_deslc.rename(columns={'Grupo': 'socioeconomico'})
df_deslc = df_deslc.drop(['Cód IBGE'], axis=1)
df_deslc
# Out:
#        periodo  parto_normal  res_municipio  hosp_municipio  res_regiao_saude  \
# 0        antes          True         130260          130260              1301
# 1        antes          True         355030          355030              3501
# 2       depois         False         500270          500270              5011
# 3       depois          True         140010          140010              1401
# 4        antes          True         292740          292740              2901
# ...        ...           ...            ...             ...               ...
# 169163   antes          True         510622          510267              5114
# 169164   antes          True         510621          510340              5104
# 169165   antes          True         510621          510340              5104
# 169166   antes          True         510621          510025              5104
# 169167  depois          True         522230          530010              5212
#
#         hosp_regiao_saude     cnes  nascimentos  mun_diff  regsau_diff  ...  \
# 0                    1301  3151794        11011     False        False  ...
# 1                    3501  2077388        10426     False        False  ...
# 2                    5011     9768        10012     False        False  ...
# 3                    1401  2566168         9647     False        False  ...
# 4                    2901  3956369         9109     False        False  ...
# ...                   ...      ...          ...       ...          ...  ...
# 169163               5107  2396106            1      True         True  ...
# 169164               5101  2659107            1      True         True  ...
# 169165               5101  2311682            1      True         True  ...
# 169166               5104  2471345            1      True        False  ...
# 169167               5301    10545            1      True         True  ...
#
#        capital fronteira amazonia res_latitude res_longitude  hosp_latitude  \
# 0         True     False     True    -3.102000    -60.025002      -3.102000
# 1         True     False    False   -23.548000    -46.636002     -23.548000
# 2         True     False    False   -20.443001    -54.646000     -20.443001
# 3         True      True     True     2.820000    -60.673000       2.820000
# 4          NaN       NaN      NaN          NaN           NaN            NaN
# ...        ...       ...      ...          ...           ...            ...
# 169163   False     False     True   -13.838000    -56.084000     -15.547000
# 169164   False     False     True   -10.558000    -55.952999     -15.596000
# 169165   False     False     True   -10.558000    -55.952999     -15.596000
# 169166   False     False     True   -10.558000    -55.952999      -9.876000
# 169167   False     False    False   -15.457000    -48.889000     -15.780000
#
#         hosp_longitude  distancia     tempo  socioeconomico
# 0           -60.025002     0.0000  0.000000             4.0
# 1           -46.636002     0.0000  0.000000             5.0
# 2           -54.646000     0.0000  0.000000             4.0
# 3           -60.673000     0.0000  0.000000             2.0
# 4                  NaN     0.0000  0.000000             5.0
# ...                ...        ...       ...             ...
# 169163      -55.168999   391.9461  4.769250             2.0
# 169164      -56.097000   701.7827  9.122222             2.0
# 169165      -56.097000   701.7827  9.122222             2.0
# 169166      -56.085999   117.8282  1.871250             2.0
# 169167      -47.930000   190.0009  3.216083             2.0
#
# [169168 rows x 22 columns]

# %% [markdown]
# ## Tabela Final

# %%
path_deslc = f'{Path.home()}/Databases/GESTANTES/deslocamento.csv.gzip'
df_deslc.to_csv(path_deslc, index=False)

# %%
pd.read_csv(path_deslc, low_memory=False)
# Out:
# /var/folders/9d/972tfrtd01z2hhl836z97zdr0000gn/T/ipykernel_30415/1965355593.py:1: DtypeWarning:
#
# Columns (12,13,14) have mixed types. Specify dtype option on import or set low_memory=False.
#        periodo  parto_normal  res_municipio  hosp_municipio  res_regiao_saude  \
# 0        antes          True         130260          130260              1301
# 1        antes          True         355030          355030              3501
# 2       depois         False         500270          500270              5011
# 3       depois          True         140010          140010              1401
# 4        antes          True         292740          292740              2901
# ...        ...           ...            ...             ...               ...
# 169163   antes          True         510622          510267              5114
# 169164   antes          True         510621          510340              5104
# 169165   antes          True         510621          510340              5104
# 169166   antes          True         510621          510025              5104
# 169167  depois          True         522230          530010              5212
#
#         hosp_regiao_saude     cnes  nascimentos  mun_diff  regsau_diff  ...  \
# 0                    1301  3151794        11011     False        False  ...
# 1                    3501  2077388        10426     False        False  ...
# 2                    5011     9768        10012     False        False  ...
# 3                    1401  2566168         9647     False        False  ...
# 4                    2901  3956369         9109     False        False  ...
# ...                   ...      ...          ...       ...          ...  ...
# 169163               5107  2396106            1      True         True  ...
# 169164               5101  2659107            1      True         True  ...
# 169165               5101  2311682            1      True         True  ...
# 169166               5104  2471345            1      True        False  ...
# 169167               5301    10545            1      True         True  ...
#
#        capital fronteira amazonia res_latitude res_longitude  hosp_latitude  \
# 0         True     False     True    -3.102000    -60.025002      -3.102000
# 1         True     False    False   -23.548000    -46.636002     -23.548000
# 2         True     False    False   -20.443001    -54.646000     -20.443001
# 3         True      True     True     2.820000    -60.673000       2.820000
# 4          NaN       NaN      NaN          NaN           NaN            NaN
# ...        ...       ...      ...          ...           ...            ...
# 169163   False     False     True   -13.838000    -56.084000     -15.547000
# 169164   False     False     True   -10.558000    -55.952999     -15.596000
# 169165   False     False     True   -10.558000    -55.952999     -15.596000
# 169166   False     False     True   -10.558000    -55.952999      -9.876000
# 169167   False     False    False   -15.457000    -48.889000     -15.780000
#
#         hosp_longitude  distancia     tempo  socioeconomico
# 0           -60.025002     0.0000  0.000000             4.0
# 1           -46.636002     0.0000  0.000000             5.0
# 2           -54.646000     0.0000  0.000000             4.0
# 3           -60.673000     0.0000  0.000000             2.0
# 4                  NaN     0.0000  0.000000             5.0
# ...                ...        ...       ...             ...
# 169163      -55.168999   391.9461  4.769250             2.0
# 169164      -56.097000   701.7827  9.122222             2.0
# 169165      -56.097000   701.7827  9.122222             2.0
# 169166      -56.085999   117.8282  1.871250             2.0
# 169167      -47.930000   190.0009  3.216083             2.0
#
# [169168 rows x 22 columns]

# %%
df_deslc = df_deslc[[
  'periodo', 'parto_normal', 'cnes',
  'res_municipio', 'hosp_municipio',
  'res_regiao_saude', 'hosp_regiao_saude',
  'mun_diff', 'regsau_diff',
  'regiao', 'uf',
  'capital', 'fronteira', 'amazonia', 'socioeconomico',
  'res_latitude', 'res_longitude',
  'hosp_latitude', 'hosp_longitude',
  'distancia', 'tempo',
  'nascimentos']]
df_deslc
# Out:
#        periodo  parto_normal     cnes  res_municipio  hosp_municipio  \
# 0        antes          True  3151794         130260          130260
# 1        antes          True  2077388         355030          355030
# 2       depois         False     9768         500270          500270
# 3       depois          True  2566168         140010          140010
# 4        antes          True  3956369         292740          292740
# ...        ...           ...      ...            ...             ...
# 169163   antes          True  2396106         510622          510267
# 169164   antes          True  2659107         510621          510340
# 169165   antes          True  2311682         510621          510340
# 169166   antes          True  2471345         510621          510025
# 169167  depois          True    10545         522230          530010
#
#         res_regiao_saude  hosp_regiao_saude  mun_diff  regsau_diff  \
# 0                   1301               1301     False        False
# 1                   3501               3501     False        False
# 2                   5011               5011     False        False
# 3                   1401               1401     False        False
# 4                   2901               2901     False        False
# ...                  ...                ...       ...          ...
# 169163              5114               5107      True         True
# 169164              5104               5101      True         True
# 169165              5104               5101      True         True
# 169166              5104               5104      True        False
# 169167              5212               5301      True         True
#
#               regiao  ... fronteira amazonia socioeconomico res_latitude  \
# 0              Norte  ...     False     True            4.0    -3.102000
# 1            Sudeste  ...     False    False            5.0   -23.548000
# 2       Centro-Oeste  ...     False    False            4.0   -20.443001
# 3              Norte  ...      True     True            2.0     2.820000
# 4                NaN  ...       NaN      NaN            5.0          NaN
# ...              ...  ...       ...      ...            ...          ...
# 169163  Centro-Oeste  ...     False     True            2.0   -13.838000
# 169164  Centro-Oeste  ...     False     True            2.0   -10.558000
# 169165  Centro-Oeste  ...     False     True            2.0   -10.558000
# 169166  Centro-Oeste  ...     False     True            2.0   -10.558000
# 169167  Centro-Oeste  ...     False    False            2.0   -15.457000
#
#         res_longitude  hosp_latitude  hosp_longitude  distancia     tempo  \
# 0          -60.025002      -3.102000      -60.025002     0.0000  0.000000
# 1          -46.636002     -23.548000      -46.636002     0.0000  0.000000
# 2          -54.646000     -20.443001      -54.646000     0.0000  0.000000
# 3          -60.673000       2.820000      -60.673000     0.0000  0.000000
# 4                 NaN            NaN             NaN     0.0000  0.000000
# ...               ...            ...             ...        ...       ...
# 169163     -56.084000     -15.547000      -55.168999   391.9461  4.769250
# 169164     -55.952999     -15.596000      -56.097000   701.7827  9.122222
# 169165     -55.952999     -15.596000      -56.097000   701.7827  9.122222
# 169166     -55.952999      -9.876000      -56.085999   117.8282  1.871250
# 169167     -48.889000     -15.780000      -47.930000   190.0009  3.216083
#
#         nascimentos
# 0             11011
# 1             10426
# 2             10012
# 3              9647
# 4              9109
# ...             ...
# 169163            1
# 169164            1
# 169165            1
# 169166            1
# 169167            1
#
# [169168 rows x 22 columns]

# %%
df_deslc.to_csv(path_deslc, index=False)
df_deslc.to_excel(path_deslc.replace('csv.gzip', 'xlsx'))

# %% [markdown]
# ## RJ

# %%
df_deslc_rj = df_deslc[df_deslc['uf'] == 'RJ']
df_deslc_rj
# Out:
#        periodo  parto_normal     cnes  res_municipio  hosp_municipio  \
# 12       antes          True  2295407         330455          330455
# 16      depois          True  2270609         330455          330455
# 19       antes          True  2280248         330455          330455
# 25       antes          True  2270609         330455          330455
# 28      depois          True  2280248         330455          330455
# ...        ...           ...      ...            ...             ...
# 159578   antes          True  2288109         330555          330260
# 159579   antes          True  2281589         330555          330227
# 159580   antes          True  2270714         330550          330455
# 159581   antes          True  2269783         330550          330455
# 159582   antes          True  2275562         330540          330390
#
#         res_regiao_saude  hosp_regiao_saude  mun_diff  regsau_diff   regiao  \
# 12                  3305               3305     False        False  Sudeste
# 16                  3305               3305     False        False  Sudeste
# 19                  3305               3305     False        False  Sudeste
# 25                  3305               3305     False        False  Sudeste
# 28                  3305               3305     False        False  Sudeste
# ...                  ...                ...       ...          ...      ...
# 159578              3305               3305      True        False  Sudeste
# 159579              3305               3305      True        False  Sudeste
# 159580              3302               3305      True         True  Sudeste
# 159581              3302               3305      True         True  Sudeste
# 159582              3303               3308      True         True  Sudeste
#
#         ... fronteira amazonia socioeconomico res_latitude  res_longitude  \
# 12      ...     False    False            5.0   -22.903000     -43.208000
# 16      ...     False    False            5.0   -22.903000     -43.208000
# 19      ...     False    False            5.0   -22.903000     -43.208000
# 25      ...     False    False            5.0   -22.903000     -43.208000
# 28      ...     False    False            5.0   -22.903000     -43.208000
# ...     ...       ...      ...            ...          ...            ...
# 159578  ...     False    False            5.0   -22.743999     -43.708000
# 159579  ...     False    False            5.0   -22.743999     -43.708000
# 159580  ...     False    False            4.0   -22.920000     -42.509998
# 159581  ...     False    False            4.0   -22.920000     -42.509998
# 159582  ...     False    False            3.0   -21.995001     -42.914001
#
#         hosp_latitude  hosp_longitude  distancia     tempo  nascimentos
# 12         -22.903000      -43.208000     0.0000  0.000000         7914
# 16         -22.903000      -43.208000     0.0000  0.000000         7303
# 19         -22.903000      -43.208000     0.0000  0.000000         7121
# 25         -22.903000      -43.208000     0.0000  0.000000         6855
# 28         -22.903000      -43.208000     0.0000  0.000000         6568
# ...               ...             ...        ...       ...          ...
# 159578     -22.959999      -44.041000    49.0472  0.669389            1
# 159579     -22.643000      -43.653000    18.2023  0.390139            1
# 159580     -22.903000      -43.208000    88.6640  1.501028            1
# 159581     -22.903000      -43.208000    88.6640  1.501028            1
# 159582     -22.504999      -43.179001    98.4733  1.504806            1
#
# [5057 rows x 22 columns]

# %%
df_deslc_rj.to_excel(path_deslc.replace('.csv.gzip', '_rj.xlsx'), index=False)

# %%
df_deslc_rj['periodo'].value_counts()
# Out:
# antes     2602
# depois    2455
# Name: periodo, dtype: int64
