# %%
import pandas as pd
from utils import get_path
from datatable import dt, f
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
output_deslc = get_path('GESTANTES', 'deslocamentos.csv.gzip')
df_deslc = pd.read_csv(output_deslc)
df_deslc
# Out:
#         bienio  parto_normal  origem  destino  mun_diff  regsau_diff  \
# 0            0             1  355030   355030         0            0
# 1            0             1  130260   130260         0            0
# 2            0             1  120040   120040         0            0
# 3            0             1  160030   160030         0            0
# 4            0             1  150180   150180         0            0
# ...        ...           ...     ...      ...       ...          ...
# 123865       1             1  315980   270430         1            1
# 123866       1             1  350400   270430         1            1
# 123867       1             1  351880   270430         1            1
# 123868       1             1  354100   270430         1            1
# 123869       1             1  510623   270430         1            1
#
#         distancia      tempo regiao  uf  ...  capital  socioecon  latitude  \
# 0          0.0000   0.000000     SD  SP  ...        1          5   -23.548
# 1          0.0000   0.000000     NT  AM  ...        1          4    -3.102
# 2          0.0000   0.000000     NT  AC  ...        1          2    -9.975
# 3          0.0000   0.000000     NT  AP  ...        1          2     0.039
# 4          0.0000   0.000000     NT  PA  ...        0          1    -1.682
# ...           ...        ...    ...  ..  ...      ...        ...       ...
# 123865  2275.6718  28.283556     SD  MG  ...        0          5   -18.839
# 123866  2599.6191  31.918583     SD  SP  ...        0          4   -22.662
# 123867  2404.7096  29.901278     SD  SP  ...        0          4   -23.463
# 123868  2490.4019  31.241472     SD  SP  ...        0          4   -24.006
# 123869  3217.7273  39.940667     CO  MT  ...        0          2   -14.797
#
#         longitude  hosp_latitude  hosp_longitude  hosp_cnes  \
# 0         -46.636        -23.548         -46.636    2077701
# 1         -60.025         -3.102         -60.025    3004104
# 2         -67.810         -9.975         -67.810    2000733
# 3         -51.066          0.039         -51.066    2020068
# 4         -50.480         -1.682         -50.480    2418657
# ...           ...            ...             ...        ...
# 123865    -50.121         -9.666         -35.735    9923837
# 123866    -50.412         -9.666         -35.735    9923837
# 123867    -46.533         -9.666         -35.735    9923837
# 123868    -46.403         -9.666         -35.735    9923837
# 123869    -57.288         -9.666         -35.735    9923837
#
#         hosp_regiao_saude  hosp_uf count
# 0                    3501       SP    76
# 1                    1301       AM    74
# 2                    1201       AC    73
# 3                    1601       AP    73
# 4                    1508       PA    73
# ...                   ...      ...   ...
# 123865               2701       AL     1
# 123866               2701       AL     1
# 123867               2701       AL     1
# 123868               2701       AL     1
# 123869               2701       AL     1
#
# [123870 rows x 21 columns]

# %%
df_deslc.to_excel(output_deslc.replace('csv.gzip', 'xlsx'), index=False)

# %%
df_deslc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97665 entries, 0 to 97664
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   bienio             97665 non-null  int64
#  1   parto_normal       97665 non-null  int64
#  2   origem             97665 non-null  int64
#  3   destino            97665 non-null  int64
#  4   mun_diff           97665 non-null  int64
#  5   regsau_diff        97665 non-null  int64
#  6   distancia          97665 non-null  float64
#  7   tempo              97665 non-null  float64
#  8   regiao             97665 non-null  object
#  9   uf                 97665 non-null  object
#  10  regiao_saude       97665 non-null  int64
#  11  capital            97665 non-null  int64
#  12  socioecon          97665 non-null  int64
#  13  latitude           97665 non-null  float64
#  14  longitude          97665 non-null  float64
#  15  hosp_latitude      97665 non-null  float64
#  16  hosp_longitude     97665 non-null  float64
#  17  hosp_regiao_saude  97665 non-null  int64
#  18  count              97665 non-null  int64
# dtypes: float64(6), int64(11), object(2)
# memory usage: 14.2+ MB

# %%
df_deslc['count'].sum()
# Out:
# 1350318

# %%
regioes = df_deslc['regiao'].unique()
regioes
# Out:
# array(['Sudeste', 'Nordeste', 'Norte', 'Centro-Oeste', 'Sul'],
#       dtype=object)

# %%
desc_regiao = dict()
for regiao in regioes:
  desc_regiao[regiao] = df_deslc[df_deslc['regiao'] == regiao]

# %%
desc_regiao[regioes[0]]
# Out:
#        bienio  parto_normal  origem  destino  mun_diff  regsau_diff  \
# 0           0             1  355030   355030         0            0
# 1           0             0  355030   355030         0            0
# 2           0             1  330455   330455         0            0
# 3           0             0  330455   330455         0            0
# 14          0             1  310620   310620         0            0
# ...       ...           ...     ...      ...       ...          ...
# 97494       1             1  313440   521150         1            1
# 97552       1             1  330100   521760         1            1
# 97625       1             1  353730   522040         1            1
# 97626       1             1  354340   522040         1            1
# 97640       1             1  312950   522045         1            1
#
#        distancia      tempo   regiao  uf  regiao_saude  capital  socioecon  \
# 0         0.0000   0.000000  Sudeste  SP          3501        1          5
# 1         0.0000   0.000000  Sudeste  SP          3501        1          5
# 2         0.0000   0.000000  Sudeste  RJ          3305        1          5
# 3         0.0000   0.000000  Sudeste  RJ          3305        1          5
# 14        0.0000   0.000000  Sudeste  MG          3101        1          1
# ...          ...        ...      ...  ..           ...      ...        ...
# 97494   274.7725   3.272722  Sudeste  MG          3113        0          3
# 97552  1232.6051  15.700639  Sudeste  RJ          3307        0          5
# 97625   356.4371   5.702722  Sudeste  SP          3506        0          3
# 97626   449.7193   6.066944  Sudeste  SP          3518        0          5
# 97640   598.9450   7.536861  Sudeste  MG          3113        0          3
#
#        latitude  longitude  hosp_latitude  hosp_longitude  hosp_regiao_saude  \
# 0       -23.548    -46.636        -23.548         -46.636               3501
# 1       -23.548    -46.636        -23.548         -46.636               3501
# 2       -22.903    -43.208        -22.903         -43.208               3305
# 3       -22.903    -43.208        -22.903         -43.208               3305
# 14      -19.817    -43.956        -19.817         -43.956               3101
# ...         ...        ...            ...             ...                ...
# 97494   -19.728    -50.196        -18.420         -49.218               5216
# 97552   -21.754    -41.324        -15.453         -47.614               5206
# 97625   -21.420    -50.078        -18.991         -50.544               5213
# 97626   -21.178    -47.810        -18.991         -50.544               5213
# 97640   -19.478    -46.539        -16.708         -49.093               5202
#
#        count
# 0       2368
# 1       2020
# 2       1210
# 3        872
# 14       466
# ...      ...
# 97494      1
# 97552      1
# 97625      1
# 97626      1
# 97640      1
#
# [26527 rows x 19 columns]

# %%
desc_regiao[regioes[0]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26527 entries, 0 to 97640
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   bienio             26527 non-null  int64
#  1   parto_normal       26527 non-null  int64
#  2   origem             26527 non-null  int64
#  3   destino            26527 non-null  int64
#  4   mun_diff           26527 non-null  int64
#  5   regsau_diff        26527 non-null  int64
#  6   distancia          26527 non-null  float64
#  7   tempo              26527 non-null  float64
#  8   regiao             26527 non-null  object
#  9   uf                 26527 non-null  object
#  10  regiao_saude       26527 non-null  int64
#  11  capital            26527 non-null  int64
#  12  socioecon          26527 non-null  int64
#  13  latitude           26527 non-null  float64
#  14  longitude          26527 non-null  float64
#  15  hosp_latitude      26527 non-null  float64
#  16  hosp_longitude     26527 non-null  float64
#  17  hosp_regiao_saude  26527 non-null  int64
#  18  count              26527 non-null  int64
# dtypes: float64(6), int64(11), object(2)
# memory usage: 4.0+ MB

# %%
df_deslc['uf'].value_counts()
# Out:
# MG    11715
# SP    10539
# BA     9845
# PE     7320
# RS     6471
# MA     5352
# PR     5322
# SC     4266
# PA     4134
# PB     3667
# CE     3581
# GO     3478
# PI     3225
# RN     3098
# RJ     2485
# MT     2161
# TO     2146
# AL     1886
# ES     1788
# SE     1262
# MS     1261
# RO     1141
# AM      832
# AC      291
# AP      228
# RR      171
# Name: uf, dtype: int64

# %%
df_deslc[df_deslc['uf'] == 'MG'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11715 entries, 14 to 97640
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   bienio             11715 non-null  int64
#  1   parto_normal       11715 non-null  int64
#  2   origem             11715 non-null  int64
#  3   destino            11715 non-null  int64
#  4   mun_diff           11715 non-null  int64
#  5   regsau_diff        11715 non-null  int64
#  6   distancia          11715 non-null  float64
#  7   tempo              11715 non-null  float64
#  8   regiao             11715 non-null  object
#  9   uf                 11715 non-null  object
#  10  regiao_saude       11715 non-null  int64
#  11  capital            11715 non-null  int64
#  12  socioecon          11715 non-null  int64
#  13  latitude           11715 non-null  float64
#  14  longitude          11715 non-null  float64
#  15  hosp_latitude      11715 non-null  float64
#  16  hosp_longitude     11715 non-null  float64
#  17  hosp_regiao_saude  11715 non-null  int64
#  18  count              11715 non-null  int64
# dtypes: float64(6), int64(11), object(2)
# memory usage: 1.8+ MB

# %%
# df_deslc.to_pandas().to_excel(output_deslc.replace('csv.gzip', 'xlsx'), index=False)
