# %% [raw]
# ---
# title: "Rede de Deslocamento"
# ---

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from pathlib import Path
from zipfile import ZipFile
from datatable import dt, f, by
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn3
from plotly import express as px, io as pio

pd.options.plotting.backend = 'plotly'
pio.renderers.default = 'plotly_mimetype+notebook_connected'
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# # Fontes de dados

# %% [markdown]
# ## Procedimentos SIH

# %%
output_proc = f'{Path.home()}/Databases/GESTANTES/procedimentos_age.csv.gzip'
df_proc = dt.fread(output_proc)

# %%
path_sihsus = f'{Path.home()}/Databases/GESTANTES/procedimentos.csv.gzip'
df_sihsus = pd.read_csv(path_sihsus)
df_sihsus
# Out:
#          ano periodo tipo_parto     cnes  hosp_cod_municipio  \
# 0       2010   antes     normal  2077701              355030
# 1       2010   antes     normal  2077388              355030
# 2       2010   antes     normal  3151794              130260
# 3       2010   antes     normal  2079186              355030
# 4       2010   antes     normal  3956369              292740
# ...      ...     ...        ...      ...                 ...
# 461271  2019  depois  cesariano  9923837              270430
# 461272  2019  depois  cesariano  9923837              270430
# 461273  2019  depois  cesariano  9923837              270430
# 461274  2019  depois  cesariano  9923837              270430
# 461275  2019  depois  cesariano  9923837              270430
#
#         hosp_regiao_saude  cod_municipio  regiao_saude  count
# 0                    3501         355030          3501   4358
# 1                    3501         355030          3501   4207
# 2                    1301         130260          1301   4145
# 3                    3501         355030          3501   4059
# 4                    2901         292740          2901   3935
# ...                   ...            ...           ...    ...
# 461271               2701         355640          3520      1
# 461272               2701         420910          4213      1
# 461273               2701         510285          5109      1
# 461274               2701         510622          5114      1
# 461275               2701         510792          5114      1
#
# [461276 rows x 9 columns]

# %%
df_sihsus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 461276 entries, 0 to 461275
# Data columns (total 9 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ano                 461276 non-null  int64
#  1   periodo             461276 non-null  object
#  2   tipo_parto          461276 non-null  object
#  3   cnes                461276 non-null  int64
#  4   hosp_cod_municipio  461276 non-null  int64
#  5   hosp_regiao_saude   461276 non-null  int64
#  6   cod_municipio       461276 non-null  int64
#  7   regiao_saude        461276 non-null  int64
#  8   count               461276 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 31.7+ MB

# %% [markdown]
# ### Criando coluna periodo

# %%
df_proc['periodo'] = df_proc['ano'].apply(
  lambda x: 'antes' if (x == 2010) | (x == 2011) else ('depois' if (x == 2018) | (x == 2019) else 'durante'))
df_proc
# Out:
#           ano tipo_parto     cnes  hosp_cod_municipio  hosp_regiao_saude  \
# 0        2011     normal  6627595              130260               1301
# 1        2012     normal  6627595              130260               1301
# 2        2011     normal  6627595              130260               1301
# 3        2012     normal  2077388              355030               3501
# 4        2011  cesariano  6627595              130260               1301
# ...       ...        ...      ...                 ...                ...
# 3355686  2019  cesariano  9923837              270430               2701
# 3355687  2019  cesariano  9923837              270430               2701
# 3355688  2019  cesariano  9923837              270430               2701
# 3355689  2019  cesariano  9923837              270430               2701
# 3355690  2019  cesariano  9923837              270430               2701
#
#          cod_municipio  regiao_saude  idade  count  periodo
# 0               130260          1301     22    519    antes
# 1               130260          1301     27    449  durante
# 2               130260          1301     21    429    antes
# 3               355030          3501     20    404  durante
# 4               130260          1301     22    402    antes
# ...                ...           ...    ...    ...      ...
# 3355686         355640          3520     29      1   depois
# 3355687         420910          4213     24      1   depois
# 3355688         510285          5109     28      1   depois
# 3355689         510622          5114     29      1   depois
# 3355690         510792          5114     14      1   depois
#
# [3355691 rows x 10 columns]

# %% [markdown]
# ## Municípios

# %%
path_muns = f'{Path.home()}/Databases/GESTANTES/municipios.csv.gzip'
df_muns = pd.read_csv(path_muns)
df_muns
# Out:
#       cod_municipio        regiao  uf  cod_uf             nome_uf  \
# 0            355030       Sudeste  SP      35           SAO PAULO
# 1            330455       Sudeste  RJ      33      RIO DE JANEIRO
# 2            130260         Norte  AM      13            AMAZONAS
# 3            230440      Nordeste  CE      23               CEARA
# 4            292740      Nordeste  BA      29               BAHIA
# ...             ...           ...  ..     ...                 ...
# 5564         520020  Centro-Oeste  GO      52               GOIAS
# 5565         510120  Centro-Oeste  MT      51         MATO GROSSO
# 5566         350640       Sudeste  SP      35           SAO PAULO
# 5567         500627  Centro-Oeste  MS      50  MATO GROSSO DO SUL
# 5568         330513       Sudeste  RJ      33      RIO DE JANEIRO
#
#               municipio               nome capital fronteira amazonia  \
# 0             São Paulo          SAO PAULO       S         N        N
# 1        Rio de Janeiro     RIO DE JANEIRO       S         N        N
# 2                Manaus             MANAUS       S         N        S
# 3             Fortaleza          FORTALEZA       S         N        N
# 4              Salvador           SALVADOR       S         N        N
# ...                 ...                ...     ...       ...      ...
# 5564         Água Limpa         AGUA LIMPA       N         N        N
# 5565         Araguainha         ARAGUAINHA       N         N        S
# 5566              Bilac              BILAC       N         N        N
# 5567  Paraíso das Águas  PARAISO DAS AGUAS       N         N        N
# 5568    São José de Ubá    SAO JOSE DE UBA       N         N        N
#
#       macroregiao_saude  regiao_saude  microregiao_saude  latitude  longitude  \
# 0                  3590          3501              35900  -23.5480   -46.6360
# 1                  3390          3305              33900  -22.9030   -43.2080
# 2                  1390          1301              13900   -3.1020   -60.0250
# 3                  2301          2301              23900   -3.7170   -38.5430
# 4                  2902          2901              29021  -12.9710   -38.5110
# ...                 ...           ...                ...       ...        ...
# 5564               5205          5216              52900  -18.0740   -48.7620
# 5565               5190          5107              51900  -16.8560   -53.0330
# 5566               3590          3506              35900  -21.4030   -50.4710
# 5567                  0             0                  0  -19.0216   -53.0116
# 5568               3390          3306              33900  -21.3580   -41.9430
#
#       altitude       area   count
# 0        760.0   1522.986  806352
# 1          2.0   1182.296  368216
# 2         92.0  11401.058  297036
# 3         21.0    313.140  203370
# 4          8.0    706.799  169924
# ...        ...        ...     ...
# 5564     682.0    452.856      25
# 5565     462.0    688.676      23
# 5566     431.0    157.278      18
# 5567       0.0   5032.469      15
# 5568      95.0    250.596       6
#
# [5569 rows x 18 columns]

# %%
df_muns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5569 entries, 0 to 5568
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   cod_municipio      5569 non-null   int64
#  1   regiao             5569 non-null   object
#  2   uf                 5569 non-null   object
#  3   cod_uf             5569 non-null   int64
#  4   nome_uf            5569 non-null   object
#  5   municipio          5569 non-null   object
#  6   nome               5569 non-null   object
#  7   capital            5569 non-null   object
#  8   fronteira          5569 non-null   object
#  9   amazonia           5569 non-null   object
#  10  macroregiao_saude  5569 non-null   int64
#  11  regiao_saude       5569 non-null   int64
#  12  microregiao_saude  5569 non-null   int64
#  13  latitude           5565 non-null   float64
#  14  longitude          5565 non-null   float64
#  15  altitude           5565 non-null   float64
#  16  area               5565 non-null   float64
#  17  count              5569 non-null   int64
# dtypes: float64(4), int64(6), object(8)
# memory usage: 783.3+ KB

# %% [markdown]
# ## Distâncias

# %%
path_dist = f'{Path.home()}/Databases/DISTANCIAS/matriz_distancias.zip'
df_dist = pd.read_csv(path_dist, low_memory=False)
df_dist
# Out:
#           origem  destino   distancia     tempo
# 0         110001   110001    0.000000  0.000000
# 1         110001   110002  309.050000  6.169056
# 2         110001   110003  399.499700  6.289056
# 3         110001   110004   81.201103  1.917750
# 4         110001   110005  391.704300  6.136361
# ...          ...      ...         ...       ...
# 31024895  530010   522200  161.728900  2.356000
# 31024896  530010   522205  382.708800  5.479556
# 31024897  530010   522220  161.603400  2.248944
# 31024898  530010   522230  190.000900  3.216083
# 31024899  530010   530010    0.000000  0.000000
#
# [31024900 rows x 4 columns]

# %%
df_dist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31024900 entries, 0 to 31024899
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   origem     int64
#  1   destino    int64
#  2   distancia  float64
#  3   tempo      float64
# dtypes: float64(2), int64(2)
# memory usage: 946.8 MB

# %% [markdown]
# ## Indicador SocioEconômico

# %%
path_socioeco = f'{Path.home()}/Databases/HEALTH/health_regions.csv'
df_socioeco = pd.read_csv(path_socioeco)
df_socioeco
# Out:
#       UF       Município  Cód IBGE  Cód Região de Saúde  \
# 0     AC      Acrelândia    120001                12002
# 1     AC    Assis Brasil    120005                12001
# 2     AC       Brasiléia    120010                12001
# 3     AC          Bujari    120013                12002
# 4     AC        Capixaba    120017                12002
# ...   ..             ...       ...                  ...
# 5566  TO  Tocantinópolis    172120                17002
# 5567  TO        Tupirama    172125                17004
# 5568  TO      Tupiratins    172130                17004
# 5569  TO    Wanderlândia    172208                17001
# 5570  TO         Xambioá    172210                17001
#
#          Nome da Região de Saúde  Grupo
# 0             Baixo Acre e Purus      2
# 1                      Alto Acre      1
# 2                      Alto Acre      1
# 3             Baixo Acre e Purus      2
# 4             Baixo Acre e Purus      2
# ...                          ...    ...
# 5566            Bico do Papagaio      1
# 5567  Cerrado Tocantins Araguaia      2
# 5568  Cerrado Tocantins Araguaia      2
# 5569        Médio Norte Araguaia      3
# 5570        Médio Norte Araguaia      3
#
# [5571 rows x 6 columns]

# %%
df_socioeco[['Cód IBGE', 'Grupo']]
# Out:
#       Cód IBGE  Grupo
# 0       120001      2
# 1       120005      1
# 2       120010      1
# 3       120013      2
# 4       120017      2
# ...        ...    ...
# 5566    172120      1
# 5567    172125      2
# 5568    172130      2
# 5569    172208      3
# 5570    172210      3
#
# [5571 rows x 2 columns]

# %% [markdown]
# # Tabela Deslocamento

# %%
cols_sih = df_sihsus.columns[1:]
df_deslc = df_sihsus[cols_sih]
df_deslc = df_deslc[df_deslc['periodo'] != 'durante']
df_deslc
# Out:
#        periodo tipo_parto     cnes  hosp_cod_municipio  hosp_regiao_saude  \
# 0        antes     normal  2077701              355030               3501
# 1        antes     normal  2077388              355030               3501
# 2        antes     normal  3151794              130260               1301
# 3        antes     normal  2079186              355030               3501
# 4        antes     normal  3956369              292740               2901
# ...        ...        ...      ...                 ...                ...
# 461271  depois  cesariano  9923837              270430               2701
# 461272  depois  cesariano  9923837              270430               2701
# 461273  depois  cesariano  9923837              270430               2701
# 461274  depois  cesariano  9923837              270430               2701
# 461275  depois  cesariano  9923837              270430               2701
#
#         cod_municipio  regiao_saude  count
# 0              355030          3501   4358
# 1              355030          3501   4207
# 2              130260          1301   4145
# 3              355030          3501   4059
# 4              292740          2901   3935
# ...               ...           ...    ...
# 461271         355640          3520      1
# 461272         420910          4213      1
# 461273         510285          5109      1
# 461274         510622          5114      1
# 461275         510792          5114      1
#
# [187189 rows x 8 columns]

# %%
df_deslc = df_deslc.groupby(
  by=list(cols_sih[:-1]), as_index=False
).sum().sort_values('count', ascending=False, ignore_index=True)
df_deslc
# Out:
#        periodo tipo_parto     cnes  hosp_cod_municipio  hosp_regiao_saude  \
# 0        antes     normal  3151794              130260               1301
# 1        antes     normal  2077701              355030               3501
# 2        antes     normal  2077388              355030               3501
# 3        antes     normal  2079186              355030               3501
# 4       depois     normal  3151794              130260               1301
# ...        ...        ...      ...                 ...                ...
# 124774  depois  cesariano  2101432              315340               3107
# 124775  depois  cesariano  2101777              313630               3107
# 124776  depois  cesariano  2101777              313630               3107
# 124777  depois  cesariano  2101777              313630               3107
# 124778  depois     normal  9923837              270430               2701
#
#         cod_municipio  regiao_saude  count
# 0              130260          1301   9330
# 1              355030          3501   8989
# 2              355030          3501   8722
# 3              355030          3501   8594
# 4              130260          1301   8524
# ...               ...           ...    ...
# 124774         314800          3107      1
# 124775         310020          3114      1
# 124776         311580          3125      1
# 124777         311680          3104      1
# 124778         510623          5105      1
#
# [124779 rows x 8 columns]

# %%
df_deslc['periodo'].value_counts()
# Out:
# depois    65116
# antes     59663
# Name: periodo, dtype: int64

# %%
df_deslc['mun_diff'] = df_deslc['cod_municipio'] != df_deslc['hosp_cod_municipio']
df_deslc['regsau_diff'] = df_deslc['regiao_saude'] != df_deslc['hosp_regiao_saude']
df_deslc
# Out:
#        periodo tipo_parto     cnes  hosp_cod_municipio  hosp_regiao_saude  \
# 0        antes     normal  3151794              130260               1301
# 1        antes     normal  2077701              355030               3501
# 2        antes     normal  2077388              355030               3501
# 3        antes     normal  2079186              355030               3501
# 4       depois     normal  3151794              130260               1301
# ...        ...        ...      ...                 ...                ...
# 124774  depois  cesariano  2101432              315340               3107
# 124775  depois  cesariano  2101777              313630               3107
# 124776  depois  cesariano  2101777              313630               3107
# 124777  depois  cesariano  2101777              313630               3107
# 124778  depois     normal  9923837              270430               2701
#
#         cod_municipio  regiao_saude  count  mun_diff  regsau_diff
# 0              130260          1301   9330     False        False
# 1              355030          3501   8989     False        False
# 2              355030          3501   8722     False        False
# 3              355030          3501   8594     False        False
# 4              130260          1301   8524     False        False
# ...               ...           ...    ...       ...          ...
# 124774         314800          3107      1      True        False
# 124775         310020          3114      1      True         True
# 124776         311580          3125      1      True         True
# 124777         311680          3104      1      True         True
# 124778         510623          5105      1      True         True
#
# [124779 rows x 10 columns]

# %%
res_cols = [
  'cod_municipio',
  'regiao',
  'uf',
  'capital',
  'fronteira',
  'amazonia',
  'latitude',
  'longitude',]

hosp_cols = [
  'cod_municipio',
  'latitude',
  'longitude',]

# %%
def merge_lat_lon(df_left, df_right, left_on, right_on):
  prefix = left_on.split('_')[0]
  df = pd.merge(df_left, df_right, how='left', left_on=left_on, right_on=right_on)
  if prefix == 'hosp':
    df = df.rename(columns={
      'latitude': f'{prefix}_latitude',
      'longitude': f'{prefix}_longitude'})
  df = df.rename(columns={'cod_municipio_x': right_on})
  return df

# %%
df_deslc_res = merge_lat_lon(df_deslc, df_muns[res_cols], 'cod_municipio', 'cod_municipio')
df_deslc_hosp = merge_lat_lon(df_deslc, df_muns[hosp_cols], 'hosp_cod_municipio', 'cod_municipio')
df_deslc_res[['hosp_latitude', 'hosp_longitude']] = df_deslc_hosp[['hosp_latitude', 'hosp_longitude']]
df_deslc = df_deslc_res
df_deslc
# Out:
#        periodo tipo_parto     cnes  hosp_cod_municipio  hosp_regiao_saude  \
# 0        antes     normal  3151794              130260               1301
# 1        antes     normal  2077701              355030               3501
# 2        antes     normal  2077388              355030               3501
# 3        antes     normal  2079186              355030               3501
# 4       depois     normal  3151794              130260               1301
# ...        ...        ...      ...                 ...                ...
# 124774  depois  cesariano  2101432              315340               3107
# 124775  depois  cesariano  2101777              313630               3107
# 124776  depois  cesariano  2101777              313630               3107
# 124777  depois  cesariano  2101777              313630               3107
# 124778  depois     normal  9923837              270430               2701
#
#         cod_municipio  regiao_saude  count  mun_diff  regsau_diff  \
# 0              130260          1301   9330     False        False
# 1              355030          3501   8989     False        False
# 2              355030          3501   8722     False        False
# 3              355030          3501   8594     False        False
# 4              130260          1301   8524     False        False
# ...               ...           ...    ...       ...          ...
# 124774         314800          3107      1      True        False
# 124775         310020          3114      1      True         True
# 124776         311580          3125      1      True         True
# 124777         311680          3104      1      True         True
# 124778         510623          5105      1      True         True
#
#               regiao  uf capital fronteira amazonia  latitude  longitude  \
# 0              Norte  AM       S         N        S    -3.102    -60.025
# 1            Sudeste  SP       S         N        N   -23.548    -46.636
# 2            Sudeste  SP       S         N        N   -23.548    -46.636
# 3            Sudeste  SP       S         N        N   -23.548    -46.636
# 4              Norte  AM       S         N        S    -3.102    -60.025
# ...              ...  ..     ...       ...      ...       ...        ...
# 124774       Sudeste  MG       N         N        N   -18.579    -46.518
# 124775       Sudeste  MG       N         N        N   -19.160    -45.446
# 124776       Sudeste  MG       N         N        N   -18.584    -49.199
# 124777       Sudeste  MG       N         N        N   -18.234    -42.840
# 124778  Centro-Oeste  MT       N         N        S   -14.797    -57.288
#
#         hosp_latitude  hosp_longitude
# 0              -3.102         -60.025
# 1             -23.548         -46.636
# 2             -23.548         -46.636
# 3             -23.548         -46.636
# 4              -3.102         -60.025
# ...               ...             ...
# 124774        -18.418         -46.418
# 124775        -17.743         -46.173
# 124776        -17.743         -46.173
# 124777        -17.743         -46.173
# 124778         -9.666         -35.735
#
# [124779 rows x 19 columns]

# %%
df_deslc = pd.merge(df_deslc, df_dist, how='left', left_on=['cod_municipio', 'hosp_cod_municipio'], right_on=['origem', 'destino'])
df_deslc = df_deslc.drop(['origem', 'destino'], axis=1)
df_deslc
# Out:
#        periodo tipo_parto     cnes  hosp_cod_municipio  hosp_regiao_saude  \
# 0        antes     normal  3151794              130260               1301
# 1        antes     normal  2077701              355030               3501
# 2        antes     normal  2077388              355030               3501
# 3        antes     normal  2079186              355030               3501
# 4       depois     normal  3151794              130260               1301
# ...        ...        ...      ...                 ...                ...
# 124774  depois  cesariano  2101432              315340               3107
# 124775  depois  cesariano  2101777              313630               3107
# 124776  depois  cesariano  2101777              313630               3107
# 124777  depois  cesariano  2101777              313630               3107
# 124778  depois     normal  9923837              270430               2701
#
#         cod_municipio  regiao_saude  count  mun_diff  regsau_diff  ...  uf  \
# 0              130260          1301   9330     False        False  ...  AM
# 1              355030          3501   8989     False        False  ...  SP
# 2              355030          3501   8722     False        False  ...  SP
# 3              355030          3501   8594     False        False  ...  SP
# 4              130260          1301   8524     False        False  ...  AM
# ...               ...           ...    ...       ...          ...  ...  ..
# 124774         314800          3107      1      True        False  ...  MG
# 124775         310020          3114      1      True         True  ...  MG
# 124776         311580          3125      1      True         True  ...  MG
# 124777         311680          3104      1      True         True  ...  MG
# 124778         510623          5105      1      True         True  ...  MT
#
#        capital fronteira amazonia latitude  longitude  hosp_latitude  \
# 0            S         N        S   -3.102    -60.025         -3.102
# 1            S         N        N  -23.548    -46.636        -23.548
# 2            S         N        N  -23.548    -46.636        -23.548
# 3            S         N        N  -23.548    -46.636        -23.548
# 4            S         N        S   -3.102    -60.025         -3.102
# ...        ...       ...      ...      ...        ...            ...
# 124774       N         N        N  -18.579    -46.518        -18.418
# 124775       N         N        N  -19.160    -45.446        -17.743
# 124776       N         N        N  -18.584    -49.199        -17.743
# 124777       N         N        N  -18.234    -42.840        -17.743
# 124778       N         N        S  -14.797    -57.288         -9.666
#
#         hosp_longitude  distancia      tempo
# 0              -60.025     0.0000   0.000000
# 1              -46.636     0.0000   0.000000
# 2              -46.636     0.0000   0.000000
# 3              -46.636     0.0000   0.000000
# 4              -60.025     0.0000   0.000000
# ...                ...        ...        ...
# 124774         -46.418    28.4474   0.531889
# 124775         -46.173   373.7197   4.552083
# 124776         -46.173   555.0323   6.626444
# 124777         -46.173   656.4867   7.842056
# 124778         -35.735  3217.7273  39.940667
#
# [124779 rows x 21 columns]

# %%
df_deslc = pd.merge(df_deslc, df_socioeco[['Cód IBGE', 'Grupo']], how='left', left_on='cod_municipio', right_on='Cód IBGE')
df_deslc = df_deslc.rename(columns={'Grupo': 'socioeconomico'})
df_deslc = df_deslc.drop(['Cód IBGE'], axis=1)
df_deslc
# Out:
#        periodo tipo_parto     cnes  hosp_cod_municipio  hosp_regiao_saude  \
# 0        antes     normal  3151794              130260               1301
# 1        antes     normal  2077701              355030               3501
# 2        antes     normal  2077388              355030               3501
# 3        antes     normal  2079186              355030               3501
# 4       depois     normal  3151794              130260               1301
# ...        ...        ...      ...                 ...                ...
# 124774  depois  cesariano  2101432              315340               3107
# 124775  depois  cesariano  2101777              313630               3107
# 124776  depois  cesariano  2101777              313630               3107
# 124777  depois  cesariano  2101777              313630               3107
# 124778  depois     normal  9923837              270430               2701
#
#         cod_municipio  regiao_saude  count  mun_diff  regsau_diff  ...  \
# 0              130260          1301   9330     False        False  ...
# 1              355030          3501   8989     False        False  ...
# 2              355030          3501   8722     False        False  ...
# 3              355030          3501   8594     False        False  ...
# 4              130260          1301   8524     False        False  ...
# ...               ...           ...    ...       ...          ...  ...
# 124774         314800          3107      1      True        False  ...
# 124775         310020          3114      1      True         True  ...
# 124776         311580          3125      1      True         True  ...
# 124777         311680          3104      1      True         True  ...
# 124778         510623          5105      1      True         True  ...
#
#        capital fronteira amazonia latitude longitude  hosp_latitude  \
# 0            S         N        S   -3.102   -60.025         -3.102
# 1            S         N        N  -23.548   -46.636        -23.548
# 2            S         N        N  -23.548   -46.636        -23.548
# 3            S         N        N  -23.548   -46.636        -23.548
# 4            S         N        S   -3.102   -60.025         -3.102
# ...        ...       ...      ...      ...       ...            ...
# 124774       N         N        N  -18.579   -46.518        -18.418
# 124775       N         N        N  -19.160   -45.446        -17.743
# 124776       N         N        N  -18.584   -49.199        -17.743
# 124777       N         N        N  -18.234   -42.840        -17.743
# 124778       N         N        S  -14.797   -57.288         -9.666
#
#         hosp_longitude  distancia      tempo  socioeconomico
# 0              -60.025     0.0000   0.000000               4
# 1              -46.636     0.0000   0.000000               5
# 2              -46.636     0.0000   0.000000               5
# 3              -46.636     0.0000   0.000000               5
# 4              -60.025     0.0000   0.000000               4
# ...                ...        ...        ...             ...
# 124774         -46.418    28.4474   0.531889               3
# 124775         -46.173   373.7197   4.552083               3
# 124776         -46.173   555.0323   6.626444               5
# 124777         -46.173   656.4867   7.842056               3
# 124778         -35.735  3217.7273  39.940667               2
#
# [124779 rows x 22 columns]

# %% [markdown]
# ## Tabela Final

# %%
path_deslc = f'{Path.home()}/Databases/GESTANTES/deslocamento.csv.gzip'
df_deslc.to_csv(path_deslc, index=False)

# %%
pd.read_csv(path_deslc, low_memory=False)
# Out:
#        periodo tipo_parto     cnes  hosp_cod_municipio  hosp_regiao_saude  \
# 0        antes     normal  3151794              130260               1301
# 1        antes     normal  2077701              355030               3501
# 2        antes     normal  2077388              355030               3501
# 3        antes     normal  2079186              355030               3501
# 4       depois     normal  3151794              130260               1301
# ...        ...        ...      ...                 ...                ...
# 124774  depois  cesariano  2101432              315340               3107
# 124775  depois  cesariano  2101777              313630               3107
# 124776  depois  cesariano  2101777              313630               3107
# 124777  depois  cesariano  2101777              313630               3107
# 124778  depois     normal  9923837              270430               2701
#
#         cod_municipio  regiao_saude  count  mun_diff  regsau_diff  ...  \
# 0              130260          1301   9330     False        False  ...
# 1              355030          3501   8989     False        False  ...
# 2              355030          3501   8722     False        False  ...
# 3              355030          3501   8594     False        False  ...
# 4              130260          1301   8524     False        False  ...
# ...               ...           ...    ...       ...          ...  ...
# 124774         314800          3107      1      True        False  ...
# 124775         310020          3114      1      True         True  ...
# 124776         311580          3125      1      True         True  ...
# 124777         311680          3104      1      True         True  ...
# 124778         510623          5105      1      True         True  ...
#
#        capital fronteira amazonia latitude longitude  hosp_latitude  \
# 0            S         N        S   -3.102   -60.025         -3.102
# 1            S         N        N  -23.548   -46.636        -23.548
# 2            S         N        N  -23.548   -46.636        -23.548
# 3            S         N        N  -23.548   -46.636        -23.548
# 4            S         N        S   -3.102   -60.025         -3.102
# ...        ...       ...      ...      ...       ...            ...
# 124774       N         N        N  -18.579   -46.518        -18.418
# 124775       N         N        N  -19.160   -45.446        -17.743
# 124776       N         N        N  -18.584   -49.199        -17.743
# 124777       N         N        N  -18.234   -42.840        -17.743
# 124778       N         N        S  -14.797   -57.288         -9.666
#
#         hosp_longitude  distancia      tempo  socioeconomico
# 0              -60.025     0.0000   0.000000               4
# 1              -46.636     0.0000   0.000000               5
# 2              -46.636     0.0000   0.000000               5
# 3              -46.636     0.0000   0.000000               5
# 4              -60.025     0.0000   0.000000               4
# ...                ...        ...        ...             ...
# 124774         -46.418    28.4474   0.531889               3
# 124775         -46.173   373.7197   4.552083               3
# 124776         -46.173   555.0323   6.626444               5
# 124777         -46.173   656.4867   7.842056               3
# 124778         -35.735  3217.7273  39.940667               2
#
# [124779 rows x 22 columns]

# %%
df_deslc = df_deslc[[
  'periodo', 'tipo_parto', 'cnes',
  'cod_municipio', 'hosp_cod_municipio',
  'regiao_saude', 'hosp_regiao_saude',
  'mun_diff', 'regsau_diff',
  'regiao', 'uf',
  'capital', 'fronteira', 'amazonia', 'socioeconomico',
  'latitude', 'longitude',
  'hosp_latitude', 'hosp_longitude',
  'distancia', 'tempo',
  'count']]
df_deslc
# Out:
#        periodo tipo_parto     cnes  cod_municipio  hosp_cod_municipio  \
# 0        antes     normal  3151794         130260              130260
# 1        antes     normal  2077701         355030              355030
# 2        antes     normal  2077388         355030              355030
# 3        antes     normal  2079186         355030              355030
# 4       depois     normal  3151794         130260              130260
# ...        ...        ...      ...            ...                 ...
# 124774  depois  cesariano  2101432         314800              315340
# 124775  depois  cesariano  2101777         310020              313630
# 124776  depois  cesariano  2101777         311580              313630
# 124777  depois  cesariano  2101777         311680              313630
# 124778  depois     normal  9923837         510623              270430
#
#         regiao_saude  hosp_regiao_saude  mun_diff  regsau_diff        regiao  \
# 0               1301               1301     False        False         Norte
# 1               3501               3501     False        False       Sudeste
# 2               3501               3501     False        False       Sudeste
# 3               3501               3501     False        False       Sudeste
# 4               1301               1301     False        False         Norte
# ...              ...                ...       ...          ...           ...
# 124774          3107               3107      True        False       Sudeste
# 124775          3114               3107      True         True       Sudeste
# 124776          3125               3107      True         True       Sudeste
# 124777          3104               3107      True         True       Sudeste
# 124778          5105               2701      True         True  Centro-Oeste
#
#         ... fronteira amazonia socioeconomico latitude  longitude  \
# 0       ...         N        S              4   -3.102    -60.025
# 1       ...         N        N              5  -23.548    -46.636
# 2       ...         N        N              5  -23.548    -46.636
# 3       ...         N        N              5  -23.548    -46.636
# 4       ...         N        S              4   -3.102    -60.025
# ...     ...       ...      ...            ...      ...        ...
# 124774  ...         N        N              3  -18.579    -46.518
# 124775  ...         N        N              3  -19.160    -45.446
# 124776  ...         N        N              5  -18.584    -49.199
# 124777  ...         N        N              3  -18.234    -42.840
# 124778  ...         N        S              2  -14.797    -57.288
#
#         hosp_latitude  hosp_longitude  distancia      tempo  count
# 0              -3.102         -60.025     0.0000   0.000000   9330
# 1             -23.548         -46.636     0.0000   0.000000   8989
# 2             -23.548         -46.636     0.0000   0.000000   8722
# 3             -23.548         -46.636     0.0000   0.000000   8594
# 4              -3.102         -60.025     0.0000   0.000000   8524
# ...               ...             ...        ...        ...    ...
# 124774        -18.418         -46.418    28.4474   0.531889      1
# 124775        -17.743         -46.173   373.7197   4.552083      1
# 124776        -17.743         -46.173   555.0323   6.626444      1
# 124777        -17.743         -46.173   656.4867   7.842056      1
# 124778         -9.666         -35.735  3217.7273  39.940667      1
#
# [124779 rows x 22 columns]

# %%
df_deslc.to_excel(path_deslc.replace('csv.gzip', 'xlsx'))

# %% [markdown]
# ## RJ

# %%
df_deslc_rj = df_deslc[df_deslc['uf'] == 'RJ']
df_deslc_rj
# Out:
#        periodo tipo_parto     cnes  res_municipio  hosp_municipio  \
# 11       antes     normal  2280248         330455          330455
# 18       antes     normal  2270609         330455          330455
# 21      depois     normal  7027397         330455          330455
# 22      depois     normal  2270609         330455          330455
# 24      depois     normal  2798662         330350          330350
# ...        ...        ...      ...            ...             ...
# 121177   antes     normal  2296241         330455          330430
# 121178   antes     normal  5042488         330455          330330
# 121180   antes     normal  6146376         330455          330185
# 121181   antes     normal  2280868         330455          330010
# 121182   antes     normal  2448203         330455          320245
#
#         res_regiao_saude  hosp_regiao_saude  mun_diff  regsau_diff   regiao  \
# 11                  3305               3305     False        False  Sudeste
# 18                  3305               3305     False        False  Sudeste
# 21                  3305               3305     False        False  Sudeste
# 22                  3305               3305     False        False  Sudeste
# 24                  3305               3305     False        False  Sudeste
# ...                  ...                ...       ...          ...      ...
# 121177              3305               3302      True         True  Sudeste
# 121178              3305               3305      True        False  Sudeste
# 121180              3305               3305      True        False  Sudeste
# 121181              3305               3301      True         True  Sudeste
# 121182              3305               3202      True         True  Sudeste
#
#         ... fronteira amazonia socioeconomico res_latitude  res_longitude  \
# 11      ...     False    False              5   -22.903000        -43.208
# 18      ...     False    False              5   -22.903000        -43.208
# 21      ...     False    False              5   -22.903000        -43.208
# 22      ...     False    False              5   -22.903000        -43.208
# 24      ...     False    False              5   -22.759001        -43.451
# ...     ...       ...      ...            ...          ...            ...
# 121177  ...     False    False              5   -22.903000        -43.208
# 121178  ...     False    False              5   -22.903000        -43.208
# 121180  ...     False    False              5   -22.903000        -43.208
# 121181  ...     False    False              5   -22.903000        -43.208
# 121182  ...     False    False              5   -22.903000        -43.208
#
#         hosp_latitude  hosp_longitude  distancia     tempo  nascimentos
# 11         -22.903000      -43.208000     0.0000  0.000000         6738
# 18         -22.903000      -43.208000     0.0000  0.000000         6250
# 21         -22.903000      -43.208000     0.0000  0.000000         5991
# 22         -22.903000      -43.208000     0.0000  0.000000         5986
# 24         -22.759001      -43.451000     0.0000  0.000000         5973
# ...               ...             ...        ...       ...          ...
# 121177     -22.708000      -42.625999    75.5213  0.979028            1
# 121178     -22.882999      -43.104000    17.8948  0.306417            1
# 121180     -22.537001      -42.981998    73.8015  0.981694            1
# 121181     -23.007000      -44.318001   154.9166  2.006583            1
# 121182     -20.233999      -41.511002   497.5082  6.306889            1
#
# [3464 rows x 22 columns]

# %%
df_deslc_rj.to_excel(path_deslc.replace('.csv.gzip', '_rj.xlsx'), index=False)

# %%
df_deslc_rj['periodo'].value_counts()
# Out:
# depois    2127
# antes     1337
# Name: periodo, dtype: int64

# %%
df_deslc_rj['tipo_parto'].value_counts()
# Out:
# normal       1887
# cesariano    1577
# Name: tipo_parto, dtype: int64
