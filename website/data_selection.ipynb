# %% [raw]
# ---
# title: "Seleção dos Dados"
# ---

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from pathlib import Path
from zipfile import ZipFile
from datatable import dt, f, by
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn3
from plotly import express as px, io as pio

pd.options.plotting.backend = 'plotly'
pio.renderers.default = 'plotly_mimetype+notebook_connected'
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# ## SINASC com filtros básicos

# %%
path_zip_sinasc = f'{Path.home()}/Databases/SINASC/SINASC.csv.gzip'
df_sinasc = pd.read_csv(path_zip_sinasc)
df_sinasc
# Out:
#            ano     cnes  hosp_municipio  res_municipio  hosp_regiao_saude  \
# 0         2010  2515598          110002         120040               1104
# 1         2010  3792595          110011         120040               1101
# 2         2010  2798484          110030         120040               1103
# 3         2010  5701929          120001         120001               1201
# 4         2010  5701929          120001         120001               1201
# ...        ...      ...             ...            ...                ...
# 28197159  2019  3427633          520870         170950               5201
# 28197160  2019    10537          530010         170240               5301
# 28197161  2019  5717515          530010         170610               5301
# 28197162  2019  5717515          530010         172100               5301
# 28197163  2019  3019608          530010         170240               5301
#
#           res_regiao_saude tipo_parto  n_gestados  n_pre_natal  idade  \
# 0                     1201    Cesáreo           1            4     24
# 1                     1201    Cesáreo           1            3     22
# 2                     1201    Vaginal           1            4     20
# 3                     1201    Vaginal           1            3     21
# 4                     1201    Vaginal           1            3     31
# ...                    ...        ...         ...          ...    ...
# 28197159              1707    Cesáreo           1            4     29
# 28197160              1709    Cesáreo           1            3     36
# 28197161              1710    Cesáreo           1            3     21
# 28197162              1705    Vaginal           1            4     21
# 28197163              1709    Vaginal           1            4     30
#
#           nivel_escolaridade  raca_cor nasc_raca_cor  nasc_sexo  nasc_peso  \
# 0                          4       NaN        Branca  Masculino     3400.0
# 1                          4       NaN         Parda  Masculino     3950.0
# 2                          3       NaN        Branca  Masculino     3550.0
# 3                          4       NaN         Parda   Feminino     3000.0
# 4                          3       NaN         Parda   Feminino     3000.0
# ...                      ...       ...           ...        ...        ...
# 28197159                   5       4.0         Parda   Feminino     1700.0
# 28197160                   5       NaN      Ignorado   Ignorado     2870.0
# 28197161                   4       4.0         Parda  Masculino     2554.0
# 28197162                   4       4.0         Parda   Feminino     2610.0
# 28197163                   5       4.0         Parda  Masculino     2975.0
#
#           nasc_apgar1  nasc_apgar5
# 0                 9.0         10.0
# 1                 8.0          9.0
# 2                 8.0          9.0
# 3                 9.0         10.0
# 4                 9.0         10.0
# ...               ...          ...
# 28197159          7.0          8.0
# 28197160          8.0          9.0
# 28197161          8.0          9.0
# 28197162          8.0          9.0
# 28197163          9.0         10.0
#
# [28197164 rows x 17 columns]

# %% [markdown]
# ## CNES da base SIH

# %%
path_zip_sih = f'{Path.home()}/Databases/SIHSUS/sih_count.csv.gzip'
df_cnes_sih = pd.read_csv(path_zip_sih)
df_cnes_sih
# Out:
#          cnes   count
# 0        2232  101955
# 1     3151794   75209
# 2     2323397   74712
# 3     2311682   64833
# 4       26794   63700
# ...       ...     ...
# 4144  7320175       1
# 4145  7603029       1
# 4146  7621442       1
# 4147  7704364       1
# 4148  7743068       1
#
# [4149 rows x 2 columns]

# %% [markdown]
# ## Filtro SUS

# %%
df_sinasc_sus = df_sinasc.loc[
  df_sinasc['cnes'].isin(df_cnes_sih['cnes'])].copy()
df_sinasc_sus
# Out:
#            ano     cnes  hosp_municipio  res_municipio  hosp_regiao_saude  \
# 2         2010  2798484          110030         120040               1103
# 3         2010  5701929          120001         120001               1201
# 4         2010  5701929          120001         120001               1201
# 5         2010  5701929          120001         120001               1201
# 6         2010  5701929          120001         120001               1201
# ...        ...      ...             ...            ...                ...
# 28197146  2019  2361787          520110         170730               5211
# 28197149  2019  2338564          520870         171110               5201
# 28197160  2019    10537          530010         170240               5301
# 28197161  2019  5717515          530010         170610               5301
# 28197162  2019  5717515          530010         172100               5301
#
#           res_regiao_saude tipo_parto  n_gestados  n_pre_natal  idade  \
# 2                     1201    Vaginal           1            4     20
# 3                     1201    Vaginal           1            3     21
# 4                     1201    Vaginal           1            3     31
# 5                     1201    Vaginal           1            4     23
# 6                     1201    Vaginal           1            4     26
# ...                    ...        ...         ...          ...    ...
# 28197146              1710    Cesáreo           1            3     18
# 28197149              1704    Cesáreo           1            4     27
# 28197160              1709    Cesáreo           1            3     36
# 28197161              1710    Cesáreo           1            3     21
# 28197162              1705    Vaginal           1            4     21
#
#           nivel_escolaridade  raca_cor nasc_raca_cor  nasc_sexo  nasc_peso  \
# 2                          3       NaN        Branca  Masculino     3550.0
# 3                          4       NaN         Parda   Feminino     3000.0
# 4                          3       NaN         Parda   Feminino     3000.0
# 5                          3       NaN         Parda  Masculino     3900.0
# 6                          4       NaN         Parda   Feminino     3250.0
# ...                      ...       ...           ...        ...        ...
# 28197146                   3       4.0         Parda   Feminino     2840.0
# 28197149                   4       4.0         Parda   Feminino     3082.0
# 28197160                   5       NaN      Ignorado   Ignorado     2870.0
# 28197161                   4       4.0         Parda  Masculino     2554.0
# 28197162                   4       4.0         Parda   Feminino     2610.0
#
#           nasc_apgar1  nasc_apgar5
# 2                 8.0          9.0
# 3                 9.0         10.0
# 4                 9.0         10.0
# 5                 7.0          9.0
# 6                 7.0         10.0
# ...               ...          ...
# 28197146          8.0          9.0
# 28197149          8.0          9.0
# 28197160          8.0          9.0
# 28197161          8.0          9.0
# 28197162          8.0          9.0
#
# [22773582 rows x 17 columns]

# %%
28197164 - 22773582
# Out:
# 5423582

# %%
5423582 / 28197164
# Out:
# 0.1923449464634103

# %% [markdown]
# ## Editar variáveis

# %%
df_sinasc_sus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22773582 entries, 2 to 28197162
# Data columns (total 17 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   ano                 int64
#  1   cnes                int64
#  2   hosp_municipio      int64
#  3   res_municipio       int64
#  4   hosp_regiao_saude   int64
#  5   res_regiao_saude    int64
#  6   tipo_parto          object
#  7   n_gestados          int64
#  8   n_pre_natal         int64
#  9   idade               int64
#  10  nivel_escolaridade  int64
#  11  raca_cor            float64
#  12  nasc_raca_cor       object
#  13  nasc_sexo           object
#  14  nasc_peso           float64
#  15  nasc_apgar1         float64
#  16  nasc_apgar5         float64
# dtypes: float64(4), int64(10), object(3)
# memory usage: 3.1+ GB

# %% [markdown]
# ### `tipo_parto`

# %%
df_sinasc_sus['tipo_parto'].value_counts()
# Out:
# Vaginal    11563626
# Cesáreo    11209956
# Name: tipo_parto, dtype: int64

# %%
parto_normal = {
  'Vaginal': True, 'Cesáreo': False}

# %%
df_sinasc_sus.loc[:, 'tipo_parto'] = df_sinasc_sus['tipo_parto'].map(parto_normal)
df_sinasc_sus = df_sinasc_sus.rename(columns={'tipo_parto': 'parto_normal'})

# %% [markdown]
# ### `raca_cor`

# %%
df_sinasc_sus['raca_cor'].value_counts()
# Out:
# 4.0    11625628
# 1.0     5830464
# 2.0     1122356
# 5.0      137716
# 3.0       61727
# 9.0       15388
# Name: raca_cor, dtype: int64

# %%
raca_cor = {
  1: 'Branca',
  2: 'Preta',
  3: 'Amarela',
  4: 'Parda',
  5: 'Indígena',
  9: np.nan
}

# %%
df_sinasc_sus.loc[:, 'raca_cor'] = df_sinasc_sus['raca_cor'].map(raca_cor)

# %% [markdown]
# ### `nasc_sexo`

# %%
df_sinasc_sus['nasc_sexo'].value_counts()
# Out:
# Masculino    11666829
# Feminino     11102679
# Ignorado         4074
# Name: nasc_sexo, dtype: int64

# %%
sexo_nasc = {
  'Feminino': True, 'Masculino': False, 'Ignorado': np.nan}

# %%
df_sinasc_sus.loc[:, 'nasc_sexo'] = df_sinasc_sus['nasc_sexo'].map(sexo_nasc)
df_sinasc_sus = df_sinasc_sus.rename(columns={'nasc_sexo': 'sexo_fem'})

# %% [markdown]
# ### `nasc_peso`

# %%
df_sinasc_sus.loc[:, 'nasc_peso'] = df_sinasc_sus['nasc_peso'].astype('Int64')

# %% [markdown]
# ### `nasc_apgar1`

# %%
df_sinasc_sus.loc[:, 'nasc_apgar1'] = df_sinasc_sus['nasc_apgar1'].astype('Int64').replace(99, np.nan)

# %%
df_sinasc_sus['nasc_apgar1'].value_counts()
# Out:
# 9     11111390
# 8      7312028
# 7      1557666
# 10      834776
# 6       577964
# 5       325601
# 4       197379
# 3       133466
# 2        96165
# 1        69305
# 0        23272
# Name: nasc_apgar1, dtype: Int64

# %% [markdown]
# ### `nasc_apgar5`

# %%
df_sinasc_sus.loc[:, 'nasc_apgar5'] = df_sinasc_sus['nasc_apgar5'].astype('Int64').replace(99, np.nan)

# %%
df_sinasc_sus['nasc_apgar5'].value_counts()
# Out:
# 10    10244119
# 9     10074459
# 8      1357308
# 7       291837
# 6       102954
# 5        56333
# 1        31028
# 4        28884
# 2        18684
# 3        18642
# 0        14524
# Name: nasc_apgar5, dtype: Int64

# %% [markdown]
# ## Dataset final

# %%
df_sinasc_sus
# Out:
#            ano     cnes  hosp_municipio  res_municipio  hosp_regiao_saude  \
# 2         2010  2798484          110030         120040               1103
# 3         2010  5701929          120001         120001               1201
# 4         2010  5701929          120001         120001               1201
# 5         2010  5701929          120001         120001               1201
# 6         2010  5701929          120001         120001               1201
# ...        ...      ...             ...            ...                ...
# 28197146  2019  2361787          520110         170730               5211
# 28197149  2019  2338564          520870         171110               5201
# 28197160  2019    10537          530010         170240               5301
# 28197161  2019  5717515          530010         170610               5301
# 28197162  2019  5717515          530010         172100               5301
#
#           res_regiao_saude  parto_normal  n_gestados  n_pre_natal  idade  \
# 2                     1201          True           1            4     20
# 3                     1201          True           1            3     21
# 4                     1201          True           1            3     31
# 5                     1201          True           1            4     23
# 6                     1201          True           1            4     26
# ...                    ...           ...         ...          ...    ...
# 28197146              1710         False           1            3     18
# 28197149              1704         False           1            4     27
# 28197160              1709         False           1            3     36
# 28197161              1710         False           1            3     21
# 28197162              1705          True           1            4     21
#
#           nivel_escolaridade raca_cor nasc_raca_cor sexo_fem  nasc_peso  \
# 2                          3      NaN        Branca    False       3550
# 3                          4      NaN         Parda     True       3000
# 4                          3      NaN         Parda     True       3000
# 5                          3      NaN         Parda    False       3900
# 6                          4      NaN         Parda     True       3250
# ...                      ...      ...           ...      ...        ...
# 28197146                   3    Parda         Parda     True       2840
# 28197149                   4    Parda         Parda     True       3082
# 28197160                   5      NaN      Ignorado      NaN       2870
# 28197161                   4    Parda         Parda    False       2554
# 28197162                   4    Parda         Parda     True       2610
#
#           nasc_apgar1  nasc_apgar5
# 2                   8            9
# 3                   9           10
# 4                   9           10
# 5                   7            9
# 6                   7           10
# ...               ...          ...
# 28197146            8            9
# 28197149            8            9
# 28197160            8            9
# 28197161            8            9
# 28197162            8            9
#
# [22773582 rows x 17 columns]

# %%
path_sinasc_sus = f'{Path.home()}/Databases/SINASC/sinasc_sus.csv.gzip'
df_sinasc_sus.to_csv(path_sinasc_sus, index=False)
