# %%
import pandas as pd
from utils import get_path
from datatable import dt, f
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .time    { background: #40CC40; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tbody td { text-align: left; }
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .sp {  opacity: 0.25;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %%
output_counts = get_path('GESTANTES', 'contagens.csv.gzip')
# df_counts = dt.fread(output_counts)
df_counts = pd.read_csv(output_counts, dtype={'identificador': str})
df_counts
# Out:
#        bienio  parto_normal                      codigo  escala          nome  \
# 0           0             0                          CO  regiao  Centro-Oeste
# 1           1             0                          CO  regiao  Centro-Oeste
# 2           0             1                          CO  regiao  Centro-Oeste
# 3           1             1                          CO  regiao  Centro-Oeste
# 4           0             0                          CO  regiao  Centro-Oeste
# ...       ...           ...                         ...     ...           ...
# 93060       1             0  SL/SC/42016/421870/2491710    cnes           NaN
# 93061       0             1  SL/SC/42016/421870/2491710    cnes           NaN
# 93062       1             1  SL/SC/42016/421870/2491710    cnes           NaN
# 93063       1             1  SL/SC/42016/421870/2491710    cnes           NaN
# 93064       1             1  SL/SC/42016/421870/2491710    cnes           NaN
#
#       identificador  criticidade   count   total     percent
# 0                CO            0   85068  445888   19.078334
# 1                CO            0  100995  445888   22.650307
# 2                CO            0  141604  445888   31.757751
# 3                CO            0  118221  445888   26.513609
# 4                CO            1    8372   51491   16.259152
# ...             ...          ...     ...     ...         ...
# 93060       2491710            2      59     207   28.502415
# 93061       2491710            2      14     207    6.763285
# 93062       2491710            2     125     207   60.386473
# 93063       2491710            3       2       2  100.000000
# 93064       2491710            4       2       2  100.000000
#
# [93065 rows x 10 columns]

# %%
df_counts[df_counts['codigo'].str.contains('/RJ')]
# Out:
#        bienio  parto_normal                      codigo escala  \
# 530         0             0                       SD/RJ     uf
# 531         1             0                       SD/RJ     uf
# 532         0             1                       SD/RJ     uf
# 533         1             1                       SD/RJ     uf
# 534         0             0                       SD/RJ     uf
# ...       ...           ...                         ...    ...
# 84206       0             0  SD/RJ/33009/330590/3584968   cnes
# 84207       0             1  SD/RJ/33009/330590/3584968   cnes
# 84208       1             1  SD/RJ/33009/330590/3584968   cnes
# 84209       1             1  SD/RJ/33009/330590/3584968   cnes
# 84210       1             1  SD/RJ/33009/330590/3584968   cnes
#
#                              nome identificador  criticidade   count   total  \
# 530                Rio de Janeiro            RJ            0   31475  338465
# 531                Rio de Janeiro            RJ            0   64571  338465
# 532                Rio de Janeiro            RJ            0  126306  338465
# 533                Rio de Janeiro            RJ            0  116113  338465
# 534                Rio de Janeiro            RJ            1    7153   73487
# ...                           ...           ...          ...     ...     ...
# 84206  HOSPITAL FRANCISCO LIMONGI       3584968            0       4      49
# 84207  HOSPITAL FRANCISCO LIMONGI       3584968            0      39      49
# 84208  HOSPITAL FRANCISCO LIMONGI       3584968            0       6      49
# 84209  HOSPITAL FRANCISCO LIMONGI       3584968            1       1       1
# 84210  HOSPITAL FRANCISCO LIMONGI       3584968            2       1       1
#
#           percent
# 530      9.299337
# 531     19.077600
# 532     37.317300
# 533     34.305763
# 534      9.733694
# ...           ...
# 84206    8.163265
# 84207   79.591837
# 84208   12.244898
# 84209  100.000000
# 84210  100.000000
#
# [2376 rows x 10 columns]
