# %% [raw]
# ---
# title: "Rede de Deslocamento"
# ---

# %%
import os
import numpy as np
import pandas as pd
from tqdm import tqdm
from pathlib import Path
from zipfile import ZipFile
from datatable import dt, f, by
import matplotlib.pyplot as plt
from matplotlib_venn import venn2, venn3
from plotly import express as px, io as pio

pd.options.plotting.backend = 'plotly'
pio.renderers.default = 'plotly_mimetype+notebook_connected'
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>

# %% [markdown]
# # Bases

# %% [markdown]
# ## SIH

# %%
path_sihsus = f'{Path.home()}/Databases/SIHSUS/SIHSUS.csv.gzip'
df_sihsus = pd.read_csv(path_sihsus, low_memory=False)
df_sihsus
# Out:
#            ano     cnes  hosp_municipio  res_municipio  hosp_regiao_saude  \
# 0         2010  2001020          120005         120005               1202
# 1         2010  2000733          120040         120040               1201
# 2         2010  2000733          120040         120040               1201
# 3         2010  2000733          120040         120040               1201
# 4         2010  2000733          120040         120040               1201
# ...        ...      ...             ...            ...                ...
# 16816986  2019  2765640          170930         171840               1704
# 16816987  2019  2765640          170930         171670               1704
# 16816988  2019  2765640          170930         171670               1704
# 16816989  2019  2765640          170930         170930               1704
# 16816990  2019  2755149          171610         171250               1708
#
#           res_regiao_saude tipo_parto  idade periodo
# 0                     1202     normal     23   antes
# 1                     1201     normal     28   antes
# 2                     1201     normal     38   antes
# 3                     1201     normal     16   antes
# 4                     1201     normal     26   antes
# ...                    ...        ...    ...     ...
# 16816986              1704  cesariano     24  depois
# 16816987              1704  cesariano     27  depois
# 16816988              1704  cesariano     22  depois
# 16816989              1704  cesariano     25  depois
# 16816990              1708  cesariano     21  depois
#
# [16816991 rows x 9 columns]

# %%
df_sihsus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16816991 entries, 0 to 16816990
# Data columns (total 9 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   ano                int64
#  1   cnes               int64
#  2   hosp_municipio     int64
#  3   res_municipio      int64
#  4   hosp_regiao_saude  int64
#  5   res_regiao_saude   int64
#  6   tipo_parto         object
#  7   idade              int64
#  8   periodo            object
# dtypes: int64(7), object(2)
# memory usage: 1.1+ GB

# %% [markdown]
# ## SINASC

# %%
path_sinasc_sus = f'{Path.home()}/Databases/SINASC/sinasc_sus.csv.gzip'
# df_sinasc = pd.read_csv(path_sinasc_sus, low_memory=False)
# df_sinasc

# %%
# df_sinasc.info()

# %% [markdown]
# ## Municípios

# %%
path_muns = f'{Path.home()}/Databases/MUNICIPIOS/municipios.csv.gzip'
df_muns = pd.read_csv(path_muns)
df_muns
# Out:
#       cod_ibge        regiao  uf  cod_uf           nome_uf  \
# 0       110000         Norte  RO      11          RONDONIA
# 1       110001         Norte  RO      11          RONDONIA
# 2       110002         Norte  RO      11          RONDONIA
# 3       110003         Norte  RO      11          RONDONIA
# 4       110004         Norte  RO      11          RONDONIA
# ...        ...           ...  ..     ...               ...
# 4789    522200  Centro-Oeste  GO      52             GOIAS
# 4790    522205  Centro-Oeste  GO      52             GOIAS
# 4791    522220  Centro-Oeste  GO      52             GOIAS
# 4792    522230  Centro-Oeste  GO      52             GOIAS
# 4793    530010  Centro-Oeste  DF      53  DISTRITO FEDERAL
#
#                     municipio                     nome  capital  fronteira  \
# 0     Município ignorado - RO  MUNICIPIO IGNORADO - RO    False      False
# 1       Alta Floresta D'Oeste    ALTA FLORESTA D'OESTE    False       True
# 2                   Ariquemes                ARIQUEMES    False      False
# 3                      Cabixi                   CABIXI    False       True
# 4                      Cacoal                   CACOAL    False      False
# ...                       ...                      ...      ...        ...
# 4789               Vianópolis               VIANOPOLIS    False      False
# 4790           Vicentinópolis           VICENTINOPOLIS    False      False
# 4791                 Vila Boa                 VILA BOA    False      False
# 4792            Vila Propício            VILA PROPICIO    False      False
# 4793                 Brasília                 BRASILIA     True      False
#
#       amazonia  macroregiao_saude  regiao_saude  microregiao_saude   latitude  \
# 0        False               1100          1100              11000   0.000000
# 1         True               1190          1102              11900 -11.929000
# 2         True               1190          1104              11900  -9.913000
# 3         True               1190          1103              11900 -13.492000
# 4         True               1190          1102              11900 -11.438000
# ...        ...                ...           ...                ...        ...
# 4789     False               5201          5202              52900 -16.742001
# 4790     False               5201          5202              52900 -17.735001
# 4791     False               5202          5206              52900 -15.038000
# 4792     False               5203          5212              52900 -15.457000
# 4793     False               5301          5301              53001 -15.780000
#
#       longitude  altitude         area
# 0      0.000000       0.0     0.000000
# 1    -61.995998     350.0  7066.702148
# 2    -63.041000     142.0  4426.558105
# 3    -60.544998     230.0  1314.354980
# 4    -61.448002     200.0  3792.637939
# ...         ...       ...          ...
# 4789 -48.515999    1002.0   954.278992
# 4790 -49.806000     646.0   737.250977
# 4791 -47.058998       0.0  1060.170044
# 4792 -48.889000     744.0  2181.574951
# 4793 -47.930000    1171.0  5801.937012
#
# [4794 rows x 17 columns]

# %%
df_muns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4794 entries, 0 to 4793
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   cod_ibge           4794 non-null   int64
#  1   regiao             4794 non-null   object
#  2   uf                 4794 non-null   object
#  3   cod_uf             4794 non-null   int64
#  4   nome_uf            4794 non-null   object
#  5   municipio          4794 non-null   object
#  6   nome               4794 non-null   object
#  7   capital            4794 non-null   bool
#  8   fronteira          4794 non-null   bool
#  9   amazonia           4794 non-null   bool
#  10  macroregiao_saude  4794 non-null   int64
#  11  regiao_saude       4794 non-null   int64
#  12  microregiao_saude  4794 non-null   int64
#  13  latitude           4790 non-null   float64
#  14  longitude          4790 non-null   float64
#  15  altitude           4790 non-null   float64
#  16  area               4790 non-null   float64
# dtypes: bool(3), float64(4), int64(5), object(5)
# memory usage: 538.5+ KB

# %% [markdown]
# ## Distâncias

# %%
path_dist = f'{Path.home()}/Databases/DISTANCIAS/matriz_distancias.zip'
df_dist = pd.read_csv(path_dist, low_memory=False)
df_dist
# Out:
#           origem  destino   distancia     tempo
# 0         110001   110001    0.000000  0.000000
# 1         110001   110002  309.050000  6.169056
# 2         110001   110003  399.499700  6.289056
# 3         110001   110004   81.201103  1.917750
# 4         110001   110005  391.704300  6.136361
# ...          ...      ...         ...       ...
# 31024895  530010   522200  161.728900  2.356000
# 31024896  530010   522205  382.708800  5.479556
# 31024897  530010   522220  161.603400  2.248944
# 31024898  530010   522230  190.000900  3.216083
# 31024899  530010   530010    0.000000  0.000000
#
# [31024900 rows x 4 columns]

# %%
df_dist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31024900 entries, 0 to 31024899
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   origem     int64
#  1   destino    int64
#  2   distancia  float64
#  3   tempo      float64
# dtypes: float64(2), int64(2)
# memory usage: 946.8 MB

# %% [markdown]
# ## Indicador SocioEconômico

# %%
path_socioeco = f'{Path.home()}/Databases/HEALTH/health_regions.csv'
df_socioeco = pd.read_csv(path_socioeco)
df_socioeco
# Out:
#       UF       Município  Cód IBGE  Cód Região de Saúde  \
# 0     AC      Acrelândia    120001                12002
# 1     AC    Assis Brasil    120005                12001
# 2     AC       Brasiléia    120010                12001
# 3     AC          Bujari    120013                12002
# 4     AC        Capixaba    120017                12002
# ...   ..             ...       ...                  ...
# 5566  TO  Tocantinópolis    172120                17002
# 5567  TO        Tupirama    172125                17004
# 5568  TO      Tupiratins    172130                17004
# 5569  TO    Wanderlândia    172208                17001
# 5570  TO         Xambioá    172210                17001
#
#          Nome da Região de Saúde  Grupo
# 0             Baixo Acre e Purus      2
# 1                      Alto Acre      1
# 2                      Alto Acre      1
# 3             Baixo Acre e Purus      2
# 4             Baixo Acre e Purus      2
# ...                          ...    ...
# 5566            Bico do Papagaio      1
# 5567  Cerrado Tocantins Araguaia      2
# 5568  Cerrado Tocantins Araguaia      2
# 5569        Médio Norte Araguaia      3
# 5570        Médio Norte Araguaia      3
#
# [5571 rows x 6 columns]

# %%
df_socioeco[['Cód IBGE', 'Grupo']]
# Out:
#       Cód IBGE  Grupo
# 0       120001      2
# 1       120005      1
# 2       120010      1
# 3       120013      2
# 4       120017      2
# ...        ...    ...
# 5566    172120      1
# 5567    172125      2
# 5568    172130      2
# 5569    172208      3
# 5570    172210      3
#
# [5571 rows x 2 columns]

# %% [markdown]
# # Tabela Deslocamento

# %%
def merge_lat_lon(df_left, df_right, left_on, right_on):
  prefix = left_on.split('_')[0]
  df = pd.merge(df_left, df_right, how='left', left_on=left_on, right_on=right_on)
  df = df.rename(columns={
    'latitude': f'{prefix}_latitude',
    'longitude': f'{prefix}_longitude'})
  df = df.drop(right_on, axis=1)
  return df

# %%
cols = ['periodo', 'tipo_parto', 'res_municipio', 'hosp_municipio', 'res_regiao_saude', 'hosp_regiao_saude', 'cnes']
df_deslc = df_sihsus[cols] # df_sinasc
df_deslc = df_deslc[df_deslc['periodo'] != 'durante']
df_deslc = df_deslc.groupby(
  cols, as_index=False
).size().sort_values('size', ascending=False, ignore_index=True)
df_deslc = df_deslc.rename(columns={'size': 'nascimentos'})
df_deslc
# Out:
#        periodo tipo_parto  res_municipio  hosp_municipio  res_regiao_saude  \
# 0        antes     normal         130260          130260              1301
# 1        antes     normal         355030          355030              3501
# 2        antes     normal         355030          355030              3501
# 3        antes     normal         355030          355030              3501
# 4       depois     normal         130260          130260              1301
# ...        ...        ...            ...             ...               ...
# 124774   antes     normal         310920          310620              3114
# 124775  depois  cesariano         520725          521020              5214
# 124776   antes     normal         310910          316370              3110
# 124777  depois  cesariano         520725          521565              5214
# 124778   antes     normal         231340          231290              2313
#
#         hosp_regiao_saude     cnes  nascimentos
# 0                    1301  3151794         9330
# 1                    3501  2077701         8989
# 2                    3501  2077388         8722
# 3                    3501  2079186         8594
# 4                    1301  3151794         8524
# ...                   ...      ...          ...
# 124774               3101    26972            1
# 124775               5204  2519593            1
# 124776               3111  2764814            1
# 124777               5204  3485536            1
# 124778               2311  2426579            1
#
# [124779 rows x 8 columns]

# %%
df_deslc['periodo'].value_counts()
# Out:
# depois    65116
# antes     59663
# Name: periodo, dtype: int64

# %%
df_deslc['mun_diff'] = df_deslc['res_municipio'] != df_deslc['hosp_municipio']
df_deslc['regsau_diff'] = df_deslc['res_regiao_saude'] != df_deslc['hosp_regiao_saude']
df_deslc
# Out:
#        periodo tipo_parto  res_municipio  hosp_municipio  res_regiao_saude  \
# 0        antes     normal         130260          130260              1301
# 1        antes     normal         355030          355030              3501
# 2        antes     normal         355030          355030              3501
# 3        antes     normal         355030          355030              3501
# 4       depois     normal         130260          130260              1301
# ...        ...        ...            ...             ...               ...
# 124774   antes     normal         310920          310620              3114
# 124775  depois  cesariano         520725          521020              5214
# 124776   antes     normal         310910          316370              3110
# 124777  depois  cesariano         520725          521565              5214
# 124778   antes     normal         231340          231290              2313
#
#         hosp_regiao_saude     cnes  nascimentos  mun_diff  regsau_diff
# 0                    1301  3151794         9330     False        False
# 1                    3501  2077701         8989     False        False
# 2                    3501  2077388         8722     False        False
# 3                    3501  2079186         8594     False        False
# 4                    1301  3151794         8524     False        False
# ...                   ...      ...          ...       ...          ...
# 124774               3101    26972            1      True         True
# 124775               5204  2519593            1      True         True
# 124776               3111  2764814            1      True         True
# 124777               5204  3485536            1      True         True
# 124778               2311  2426579            1      True         True
#
# [124779 rows x 10 columns]

# %%
res_cols = [
  'cod_ibge',
  'regiao',
  'uf',
  'capital',
  'fronteira',
  'amazonia',
  'latitude',
  'longitude',]

hosp_cols = [
  'cod_ibge',
  'latitude',
  'longitude',]

# %%
df_deslc = merge_lat_lon(df_deslc, df_muns[res_cols], 'res_municipio', 'cod_ibge')
df_deslc = merge_lat_lon(df_deslc, df_muns[hosp_cols], 'hosp_municipio', 'cod_ibge')
df_deslc
# Out:
#        periodo tipo_parto  res_municipio  hosp_municipio  res_regiao_saude  \
# 0        antes     normal         130260          130260              1301
# 1        antes     normal         355030          355030              3501
# 2        antes     normal         355030          355030              3501
# 3        antes     normal         355030          355030              3501
# 4       depois     normal         130260          130260              1301
# ...        ...        ...            ...             ...               ...
# 124776   antes     normal         310920          310620              3114
# 124777  depois  cesariano         520725          521020              5214
# 124778   antes     normal         310910          316370              3110
# 124779  depois  cesariano         520725          521565              5214
# 124780   antes     normal         231340          231290              2313
#
#         hosp_regiao_saude     cnes  nascimentos  mun_diff  regsau_diff  \
# 0                    1301  3151794         9330     False        False
# 1                    3501  2077701         8989     False        False
# 2                    3501  2077388         8722     False        False
# 3                    3501  2079186         8594     False        False
# 4                    1301  3151794         8524     False        False
# ...                   ...      ...          ...       ...          ...
# 124776               3101    26972            1      True         True
# 124777               5204  2519593            1      True         True
# 124778               3111  2764814            1      True         True
# 124779               5204  3485536            1      True         True
# 124780               2311  2426579            1      True         True
#
#               regiao  uf capital fronteira amazonia  res_latitude  \
# 0              Norte  AM    True     False     True     -3.102000
# 1            Sudeste  SP    True     False    False    -23.548000
# 2            Sudeste  SP    True     False    False    -23.548000
# 3            Sudeste  SP    True     False    False    -23.548000
# 4              Norte  AM    True     False     True     -3.102000
# ...              ...  ..     ...       ...      ...           ...
# 124776       Sudeste  MG   False     False    False    -17.872999
# 124777  Centro-Oeste  GO   False     False    False    -16.719999
# 124778       Sudeste  MG   False     False    False    -22.441000
# 124779  Centro-Oeste  GO   False     False    False    -16.719999
# 124780      Nordeste  CE   False     False    False     -3.732000
#
#         res_longitude  hosp_latitude  hosp_longitude
# 0          -60.025002      -3.102000      -60.025002
# 1          -46.636002     -23.548000      -46.636002
# 2          -46.636002     -23.548000      -46.636002
# 3          -46.636002     -23.548000      -46.636002
# 4          -60.025002      -3.102000      -60.025002
# ...               ...            ...             ...
# 124776     -44.180000     -19.816999      -43.956001
# 124777     -52.319000     -16.441999      -51.118000
# 124778     -46.351002     -22.115999      -45.054001
# 124779     -52.319000     -16.733000      -51.533001
# 124780     -40.992001      -3.674000      -40.238998
#
# [124781 rows x 19 columns]

# %%
df_deslc = pd.merge(df_deslc, df_dist, how='left', left_on=['res_municipio', 'hosp_municipio'], right_on=['origem', 'destino'])
df_deslc = df_deslc.drop(['origem', 'destino'], axis=1)
df_deslc
# Out:
#        periodo tipo_parto  res_municipio  hosp_municipio  res_regiao_saude  \
# 0        antes     normal         130260          130260              1301
# 1        antes     normal         355030          355030              3501
# 2        antes     normal         355030          355030              3501
# 3        antes     normal         355030          355030              3501
# 4       depois     normal         130260          130260              1301
# ...        ...        ...            ...             ...               ...
# 124776   antes     normal         310920          310620              3114
# 124777  depois  cesariano         520725          521020              5214
# 124778   antes     normal         310910          316370              3110
# 124779  depois  cesariano         520725          521565              5214
# 124780   antes     normal         231340          231290              2313
#
#         hosp_regiao_saude     cnes  nascimentos  mun_diff  regsau_diff  ...  \
# 0                    1301  3151794         9330     False        False  ...
# 1                    3501  2077701         8989     False        False  ...
# 2                    3501  2077388         8722     False        False  ...
# 3                    3501  2079186         8594     False        False  ...
# 4                    1301  3151794         8524     False        False  ...
# ...                   ...      ...          ...       ...          ...  ...
# 124776               3101    26972            1      True         True  ...
# 124777               5204  2519593            1      True         True  ...
# 124778               3111  2764814            1      True         True  ...
# 124779               5204  3485536            1      True         True  ...
# 124780               2311  2426579            1      True         True  ...
#
#         uf capital fronteira amazonia res_latitude  res_longitude  \
# 0       AM    True     False     True    -3.102000     -60.025002
# 1       SP    True     False    False   -23.548000     -46.636002
# 2       SP    True     False    False   -23.548000     -46.636002
# 3       SP    True     False    False   -23.548000     -46.636002
# 4       AM    True     False     True    -3.102000     -60.025002
# ...     ..     ...       ...      ...          ...            ...
# 124776  MG   False     False    False   -17.872999     -44.180000
# 124777  GO   False     False    False   -16.719999     -52.319000
# 124778  MG   False     False    False   -22.441000     -46.351002
# 124779  GO   False     False    False   -16.719999     -52.319000
# 124780  CE   False     False    False    -3.732000     -40.992001
#
#         hosp_latitude  hosp_longitude  distancia     tempo
# 0           -3.102000      -60.025002     0.0000  0.000000
# 1          -23.548000      -46.636002     0.0000  0.000000
# 2          -23.548000      -46.636002     0.0000  0.000000
# 3          -23.548000      -46.636002     0.0000  0.000000
# 4           -3.102000      -60.025002     0.0000  0.000000
# ...               ...             ...        ...       ...
# 124776     -19.816999      -43.956001   286.4915  3.550611
# 124777     -16.441999      -51.118000   172.7509  2.706389
# 124778     -22.115999      -45.054001   196.7931  3.693056
# 124779     -16.733000      -51.533001   107.2883  1.703556
# 124780      -3.674000      -40.238998    89.0676  1.151917
#
# [124781 rows x 21 columns]

# %%
df_deslc = pd.merge(df_deslc, df_socioeco[['Cód IBGE', 'Grupo']], how='left', left_on='res_municipio', right_on='Cód IBGE')
df_deslc = df_deslc.rename(columns={'Grupo': 'socioeconomico'})
df_deslc = df_deslc.drop(['Cód IBGE'], axis=1)
df_deslc
# Out:
#        periodo tipo_parto  res_municipio  hosp_municipio  res_regiao_saude  \
# 0        antes     normal         130260          130260              1301
# 1        antes     normal         355030          355030              3501
# 2        antes     normal         355030          355030              3501
# 3        antes     normal         355030          355030              3501
# 4       depois     normal         130260          130260              1301
# ...        ...        ...            ...             ...               ...
# 124776   antes     normal         310920          310620              3114
# 124777  depois  cesariano         520725          521020              5214
# 124778   antes     normal         310910          316370              3110
# 124779  depois  cesariano         520725          521565              5214
# 124780   antes     normal         231340          231290              2313
#
#         hosp_regiao_saude     cnes  nascimentos  mun_diff  regsau_diff  ...  \
# 0                    1301  3151794         9330     False        False  ...
# 1                    3501  2077701         8989     False        False  ...
# 2                    3501  2077388         8722     False        False  ...
# 3                    3501  2079186         8594     False        False  ...
# 4                    1301  3151794         8524     False        False  ...
# ...                   ...      ...          ...       ...          ...  ...
# 124776               3101    26972            1      True         True  ...
# 124777               5204  2519593            1      True         True  ...
# 124778               3111  2764814            1      True         True  ...
# 124779               5204  3485536            1      True         True  ...
# 124780               2311  2426579            1      True         True  ...
#
#        capital fronteira amazonia res_latitude res_longitude  hosp_latitude  \
# 0         True     False     True    -3.102000    -60.025002      -3.102000
# 1         True     False    False   -23.548000    -46.636002     -23.548000
# 2         True     False    False   -23.548000    -46.636002     -23.548000
# 3         True     False    False   -23.548000    -46.636002     -23.548000
# 4         True     False     True    -3.102000    -60.025002      -3.102000
# ...        ...       ...      ...          ...           ...            ...
# 124776   False     False    False   -17.872999    -44.180000     -19.816999
# 124777   False     False    False   -16.719999    -52.319000     -16.441999
# 124778   False     False    False   -22.441000    -46.351002     -22.115999
# 124779   False     False    False   -16.719999    -52.319000     -16.733000
# 124780   False     False    False    -3.732000    -40.992001      -3.674000
#
#         hosp_longitude  distancia     tempo  socioeconomico
# 0           -60.025002     0.0000  0.000000               4
# 1           -46.636002     0.0000  0.000000               5
# 2           -46.636002     0.0000  0.000000               5
# 3           -46.636002     0.0000  0.000000               5
# 4           -60.025002     0.0000  0.000000               4
# ...                ...        ...       ...             ...
# 124776      -43.956001   286.4915  3.550611               1
# 124777      -51.118000   172.7509  2.706389               3
# 124778      -45.054001   196.7931  3.693056               3
# 124779      -51.533001   107.2883  1.703556               3
# 124780      -40.238998    89.0676  1.151917               1
#
# [124781 rows x 22 columns]

# %% [markdown]
# ## Tabela Final

# %%
path_deslc = f'{Path.home()}/Databases/GESTANTES/deslocamento_sih.csv.gzip'
df_deslc.to_csv(path_deslc, index=False)

# %%
pd.read_csv(path_deslc, low_memory=False)
# Out:
#        periodo tipo_parto  res_municipio  hosp_municipio  res_regiao_saude  \
# 0        antes     normal         130260          130260              1301
# 1        antes     normal         355030          355030              3501
# 2        antes     normal         355030          355030              3501
# 3        antes     normal         355030          355030              3501
# 4       depois     normal         130260          130260              1301
# ...        ...        ...            ...             ...               ...
# 124776   antes     normal         310920          310620              3114
# 124777  depois  cesariano         520725          521020              5214
# 124778   antes     normal         310910          316370              3110
# 124779  depois  cesariano         520725          521565              5214
# 124780   antes     normal         231340          231290              2313
#
#         hosp_regiao_saude     cnes  nascimentos  mun_diff  regsau_diff  ...  \
# 0                    1301  3151794         9330     False        False  ...
# 1                    3501  2077701         8989     False        False  ...
# 2                    3501  2077388         8722     False        False  ...
# 3                    3501  2079186         8594     False        False  ...
# 4                    1301  3151794         8524     False        False  ...
# ...                   ...      ...          ...       ...          ...  ...
# 124776               3101    26972            1      True         True  ...
# 124777               5204  2519593            1      True         True  ...
# 124778               3111  2764814            1      True         True  ...
# 124779               5204  3485536            1      True         True  ...
# 124780               2311  2426579            1      True         True  ...
#
#        capital fronteira amazonia res_latitude res_longitude  hosp_latitude  \
# 0         True     False     True    -3.102000    -60.025002      -3.102000
# 1         True     False    False   -23.548000    -46.636002     -23.548000
# 2         True     False    False   -23.548000    -46.636002     -23.548000
# 3         True     False    False   -23.548000    -46.636002     -23.548000
# 4         True     False     True    -3.102000    -60.025002      -3.102000
# ...        ...       ...      ...          ...           ...            ...
# 124776   False     False    False   -17.872999    -44.180000     -19.816999
# 124777   False     False    False   -16.719999    -52.319000     -16.441999
# 124778   False     False    False   -22.441000    -46.351002     -22.115999
# 124779   False     False    False   -16.719999    -52.319000     -16.733000
# 124780   False     False    False    -3.732000    -40.992001      -3.674000
#
#         hosp_longitude  distancia     tempo  socioeconomico
# 0           -60.025002     0.0000  0.000000               4
# 1           -46.636002     0.0000  0.000000               5
# 2           -46.636002     0.0000  0.000000               5
# 3           -46.636002     0.0000  0.000000               5
# 4           -60.025002     0.0000  0.000000               4
# ...                ...        ...       ...             ...
# 124776      -43.956001   286.4915  3.550611               1
# 124777      -51.118000   172.7509  2.706389               3
# 124778      -45.054001   196.7931  3.693056               3
# 124779      -51.533001   107.2883  1.703556               3
# 124780      -40.238998    89.0676  1.151917               1
#
# [124781 rows x 22 columns]

# %%
df_deslc = df_deslc[[
  'periodo', 'tipo_parto', 'cnes',
  'res_municipio', 'hosp_municipio',
  'res_regiao_saude', 'hosp_regiao_saude',
  'mun_diff', 'regsau_diff',
  'regiao', 'uf',
  'capital', 'fronteira', 'amazonia', 'socioeconomico',
  'res_latitude', 'res_longitude',
  'hosp_latitude', 'hosp_longitude',
  'distancia', 'tempo',
  'nascimentos']]
df_deslc
# Out:
#        periodo tipo_parto     cnes  res_municipio  hosp_municipio  \
# 0        antes     normal  3151794         130260          130260
# 1        antes     normal  2077701         355030          355030
# 2        antes     normal  2077388         355030          355030
# 3        antes     normal  2079186         355030          355030
# 4       depois     normal  3151794         130260          130260
# ...        ...        ...      ...            ...             ...
# 124776   antes     normal    26972         310920          310620
# 124777  depois  cesariano  2519593         520725          521020
# 124778   antes     normal  2764814         310910          316370
# 124779  depois  cesariano  3485536         520725          521565
# 124780   antes     normal  2426579         231340          231290
#
#         res_regiao_saude  hosp_regiao_saude  mun_diff  regsau_diff  \
# 0                   1301               1301     False        False
# 1                   3501               3501     False        False
# 2                   3501               3501     False        False
# 3                   3501               3501     False        False
# 4                   1301               1301     False        False
# ...                  ...                ...       ...          ...
# 124776              3114               3101      True         True
# 124777              5214               5204      True         True
# 124778              3110               3111      True         True
# 124779              5214               5204      True         True
# 124780              2313               2311      True         True
#
#               regiao  ... fronteira amazonia socioeconomico res_latitude  \
# 0              Norte  ...     False     True              4    -3.102000
# 1            Sudeste  ...     False    False              5   -23.548000
# 2            Sudeste  ...     False    False              5   -23.548000
# 3            Sudeste  ...     False    False              5   -23.548000
# 4              Norte  ...     False     True              4    -3.102000
# ...              ...  ...       ...      ...            ...          ...
# 124776       Sudeste  ...     False    False              1   -17.872999
# 124777  Centro-Oeste  ...     False    False              3   -16.719999
# 124778       Sudeste  ...     False    False              3   -22.441000
# 124779  Centro-Oeste  ...     False    False              3   -16.719999
# 124780      Nordeste  ...     False    False              1    -3.732000
#
#         res_longitude  hosp_latitude  hosp_longitude  distancia     tempo  \
# 0          -60.025002      -3.102000      -60.025002     0.0000  0.000000
# 1          -46.636002     -23.548000      -46.636002     0.0000  0.000000
# 2          -46.636002     -23.548000      -46.636002     0.0000  0.000000
# 3          -46.636002     -23.548000      -46.636002     0.0000  0.000000
# 4          -60.025002      -3.102000      -60.025002     0.0000  0.000000
# ...               ...            ...             ...        ...       ...
# 124776     -44.180000     -19.816999      -43.956001   286.4915  3.550611
# 124777     -52.319000     -16.441999      -51.118000   172.7509  2.706389
# 124778     -46.351002     -22.115999      -45.054001   196.7931  3.693056
# 124779     -52.319000     -16.733000      -51.533001   107.2883  1.703556
# 124780     -40.992001      -3.674000      -40.238998    89.0676  1.151917
#
#         nascimentos
# 0              9330
# 1              8989
# 2              8722
# 3              8594
# 4              8524
# ...             ...
# 124776            1
# 124777            1
# 124778            1
# 124779            1
# 124780            1
#
# [124781 rows x 22 columns]

# %%
df_deslc.to_excel(path_deslc.replace('csv.gzip', 'xlsx'))

# %% [markdown]
# ## RJ

# %%
df_deslc_rj = df_deslc[df_deslc['uf'] == 'RJ']
df_deslc_rj
# Out:
#        periodo tipo_parto     cnes  res_municipio  hosp_municipio  \
# 11       antes     normal  2280248         330455          330455
# 18       antes     normal  2270609         330455          330455
# 21      depois     normal  7027397         330455          330455
# 22      depois     normal  2270609         330455          330455
# 24      depois     normal  2798662         330350          330350
# ...        ...        ...      ...            ...             ...
# 121177   antes     normal  2296241         330455          330430
# 121178   antes     normal  5042488         330455          330330
# 121180   antes     normal  6146376         330455          330185
# 121181   antes     normal  2280868         330455          330010
# 121182   antes     normal  2448203         330455          320245
#
#         res_regiao_saude  hosp_regiao_saude  mun_diff  regsau_diff   regiao  \
# 11                  3305               3305     False        False  Sudeste
# 18                  3305               3305     False        False  Sudeste
# 21                  3305               3305     False        False  Sudeste
# 22                  3305               3305     False        False  Sudeste
# 24                  3305               3305     False        False  Sudeste
# ...                  ...                ...       ...          ...      ...
# 121177              3305               3302      True         True  Sudeste
# 121178              3305               3305      True        False  Sudeste
# 121180              3305               3305      True        False  Sudeste
# 121181              3305               3301      True         True  Sudeste
# 121182              3305               3202      True         True  Sudeste
#
#         ... fronteira amazonia socioeconomico res_latitude  res_longitude  \
# 11      ...     False    False              5   -22.903000        -43.208
# 18      ...     False    False              5   -22.903000        -43.208
# 21      ...     False    False              5   -22.903000        -43.208
# 22      ...     False    False              5   -22.903000        -43.208
# 24      ...     False    False              5   -22.759001        -43.451
# ...     ...       ...      ...            ...          ...            ...
# 121177  ...     False    False              5   -22.903000        -43.208
# 121178  ...     False    False              5   -22.903000        -43.208
# 121180  ...     False    False              5   -22.903000        -43.208
# 121181  ...     False    False              5   -22.903000        -43.208
# 121182  ...     False    False              5   -22.903000        -43.208
#
#         hosp_latitude  hosp_longitude  distancia     tempo  nascimentos
# 11         -22.903000      -43.208000     0.0000  0.000000         6738
# 18         -22.903000      -43.208000     0.0000  0.000000         6250
# 21         -22.903000      -43.208000     0.0000  0.000000         5991
# 22         -22.903000      -43.208000     0.0000  0.000000         5986
# 24         -22.759001      -43.451000     0.0000  0.000000         5973
# ...               ...             ...        ...       ...          ...
# 121177     -22.708000      -42.625999    75.5213  0.979028            1
# 121178     -22.882999      -43.104000    17.8948  0.306417            1
# 121180     -22.537001      -42.981998    73.8015  0.981694            1
# 121181     -23.007000      -44.318001   154.9166  2.006583            1
# 121182     -20.233999      -41.511002   497.5082  6.306889            1
#
# [3464 rows x 22 columns]

# %%
df_deslc_rj.to_excel(path_deslc.replace('.csv.gzip', '_rj.xlsx'), index=False)

# %%
df_deslc_rj['periodo'].value_counts()
# Out:
# depois    2127
# antes     1337
# Name: periodo, dtype: int64

# %%
df_deslc_rj['tipo_parto'].value_counts()
# Out:
# normal       1887
# cesariano    1577
# Name: tipo_parto, dtype: int64
